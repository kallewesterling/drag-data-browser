# %%
import pandas as pd
import re
from datetime import datetime as dt

YEAR_RANGE = (1900, 1950)

def remove(row):
    try:
        date = dt.strptime(row.Date, '%Y-%m-%d')
    except:
        return True
    
    if YEAR_RANGE and date.year >= YEAR_RANGE[0] and date.year <= YEAR_RANGE[1]:
        pass # in the range!
    else:
        return True

    if row['Exclude from visualization'] or row['Unsure whether drag artist']:
        return True
    
    no_city = row['City'] == ''
    no_performer = row['Performer'] == ''
    no_venue = row['Venue'] == ''
    unnamed_performer = 'unnamed' in row['Performer'].lower()
    
    if no_city and no_performer and no_venue:
        return True
    
    if unnamed_performer:
        return True

    return False

def extract_addresses_dict(normalized_df):
    addresses = {}
    rows_with_addresses = normalized_df[normalized_df['Address']!='']
    warnings = []
    for x in zip(rows_with_addresses['Date'], rows_with_addresses['Source'], rows_with_addresses['Venue'], rows_with_addresses['Address']):
        date, source, venue, address = x
        if venue == '':
            warnings.append(address)
        else:
            if not venue in addresses:
                addresses[venue] = {}
            if not source in addresses[venue]:
                addresses[venue][source] = address
    if len(warnings):
        print(f'Warning: {len(warnings)} Venues with no names have addresses:')
        print('- ' + '- '.join(warnings))

    return addresses

def reverse_comment_dict(comment_dict):
    comments_reverse = {}
    for performer, comments in comment_dict.items():
        if not performer in comments_reverse:
            comments_reverse[performer] = {}
        for source, comment in comments.items():
            if not comment in comments_reverse[performer]:
                comments_reverse[performer][comment] = []
            comments_reverse[performer][comment].append(source)
    return comments_reverse
        
def get_comments(df, comment_field='Comment on edge: revue', match_field='Revue', transform=None):
    comments = {}
    rows_with_comments = df[df[comment_field]!='']
    warnings = []
    for x in zip(rows_with_comments['Date'], rows_with_comments['Source'], rows_with_comments[match_field], rows_with_comments[comment_field]):
        date, source, match, comment = x
        comment = str(comment).strip()
        if transform:
            comment = transform(comment)
        if match == '':
            warnings.append(str(comment)[:40]+'...')
        else:
            if not match in comments:
                comments[match] = {}
            if not source in comments[match]:
                comments[match][source] = comment
    if len(warnings):
        print(f'Warning: {len(warnings)} mentions in `{comment_field}` with no value have comments:')
        print('- ' + '\n- '.join(warnings))

    return comments

def get_revue_comments_dict(df):
    return get_comments(df, 'Comment on edge: revue', 'Revue')

def get_performer_comments_dict(df):
    return get_comments(df, 'Comment on node: performer', 'Performer')

def get_venue_comments_dict(df):
    return get_comments(df, 'Comment on node: venue', 'Venue')

def get_city_comments_dict(df):
    return get_comments(df, 'Comment on node: city', 'City')

def get_true_value(row, type):
    if type == 'source':
        if row['Source clean'] != '':
            return row['Source clean']
        return row['Source']
    if type == 'performer':
        if row['Normalized performer'] != '':
            return row['Normalized performer']
        if row['Performer first-name'] != '' and row['Performer last-name'] != '':
            return row['Normalized performer']
        return row['Performer']
    if type == 'city':
        if row['Normalized City'] != '':
            return row['Normalized City']
        return row['City']
    if type == 'revue':
        if row['Normalized Revue Name'] != '':
            return row['Normalized Revue Name']
        return row['Revue name']
    if type == 'venue':
        if row['Normalized Venue'] != '':
            return row['Normalized Venue']
        return row['Venue']
    raise NotImplementedError(f'type `{type}` is not yet implemented')

def find_ref(row, eima=True):
    source = row['Source']
    source += ' ' + row['EIMA']
    source += ' ' + row['Search (newspapers.com)']
    source += ' ' + row['Source clean']
    
    is_eima = 'eima' in source.lower() or 'variety' in source.lower() or 'billboard' in source.lower()
    has_ref = re.search(r'(\d{7,10})', source)
    refs = list(set(re.findall(r'(\d{7,10})', source)))
    if has_ref and eima and is_eima:
        return '|'.join(refs)
    
    if has_ref and not eima and not is_eima:
        return '|'.join(refs)

    return ''
    

df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')
df = df.fillna('')
df = df.replace('—', '')
df = df.replace('—*', '')

# %%
# First, set up our references to EIMA and newspapers.com
df['EIMA'] = df.apply(lambda row: find_ref(row), axis=1)
df['Newspapers.com'] = df.apply(lambda row: find_ref(row, False), axis=1)

# Normalize dataframe
df['Source'] = df.apply(lambda row: get_true_value(row, 'source'), axis=1)
df['Venue'] = df.apply(lambda row: get_true_value(row, 'venue'), axis=1)
df['Performer'] = df.apply(lambda row: get_true_value(row, 'performer'), axis=1)
df['City'] = df.apply(lambda row: get_true_value(row, 'city'), axis=1)
df['Revue'] = df.apply(lambda row: get_true_value(row, 'revue'), axis=1)

# %%
# Drop filtered data
df['remove'] = df.apply(lambda row: remove(row), axis=1)
df = df.drop(df[df['remove']==True].index)

# %%
sources = list(set([x for x in df['Source'].sort_values()]))
billboards = [x for x in sources if 'billboard' in x.lower()]

# %%
afroamericans = [x for x in sources if 'baltimore afro-american' in x.lower()]

# %%
# Load up the billboard and the variety

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys

try:
    b.get('https://www-proquest-com.proxy.library.nyu.edu/eima')
except:
    b = webdriver.Firefox()
    b.get('https://www-proquest-com.proxy.library.nyu.edu/eima')

# %%
input('login')
# Out:
# login
# ''

# %%
import time, random, json
from pathlib import Path

# %%
billboards
# Out:
# ['Billboard, October 11, 1947, 91',
#  'Billboard, June 21, 1930, 16 (Vaudeville Reviews: The Palace, New York)',
#  'Billboard, March 28, 1936, page unknown (Route Department)',
#  'Billboard, July 5, 1947, 45',
#  'Billboard, January 27, 1930, 49',
#  'Billboard, August 1, 1936, 19 (Club Chatter)',
#  'Billboard, May 27, 1944, page unknown',
#  'Billboard, November 19, 1938, 18',
#  'Billboard, September 10, 1932, 7 (Collier Returning to America)',
#  'Billboard, January 17, 1948, 73',
#  'Billboard, August 31, 1935, 14 (Round the Tables)',
#  'Billboard, May 29, 1937, 37 (Club Chatter)',
#  'Billboard, August 28, 1948, 48 (Uno)',
#  'Billboard, May 14, 1938, 18',
#  'Billboard, December 5, 1936, 14 (Club Chatter)',
#  'Billboard, March 11, 1944, 25 (Advertisement)',
#  'Billboard, January 27, 1940, page unknown',
#  'Billboard, July 17, 1948, 91',
#  "Billboard, June 7, 1930, 16 (VAUDEVILLE REVIEWS: Loew's State, New York)",
#  'Billboard, January 1, 1938, 29',
#  'Billboard, September 4, 1937, 14',
#  'Billboard, March 17, 1937, 49',
#  'Billboard, March 15, 1947, 88',
#  'Billboard, June 14, 1942, page unknown',
#  'Billboard, January 22, 1938, 8 (Night Club Reviews - Chateau Club, Cleveland)',
#  'Billboard, March 8, 1930, 51',
#  "Billboard, January 19, 1935, 12 (NIGHT CLUB REVIEWS - King's Terrace, New York)",
#  'Billboard, January 23, 1937, 13',
#  'Billboard, May 10, 1947, 94',
#  'Billboard, November 30, 1935, 14',
#  'Billboard, November 29, 1930, 32',
#  'Billboard, May 31, 1947, 85',
#  'Billboard, August 8, 1936, 12',
#  'Billboard, October 2, 1948, 71',
#  'Billboard, November 15, 1947, 80',
#  'Billboard, December 27, 1947, 71',
#  'Billboard, June 11, 1949, page unknown',
#  'Billboard, December 21, 1946, page unknown',
#  'Billboard, January 5, 1929, 17 (Vaudeville Notes)',
#  'Billboard, May 22, 1937 (Route Department)',
#  'Billboard, September 9, 1933, 11',
#  'Billboard, June 25, 1938, 17',
#  'Billboard, October 11, 1930, 31',
#  'Billboard, January 20, 1934, 6 (Vaudeville: Another All-Girl Revue)',
#  'Billboard, March 4, 1950, 68',
#  "Billboard, June 5, 1943, 15 (Night Club Reviews - Colosimo's, Chicago)",
#  'Billboard, May 15, 1948, 91',
#  'Billboard, March 14, 1936, page unknown (Route Department)',
#  'Billboard, January 14, 1950, 78',
#  'Billboard, December 6, 1930, 22',
#  'Billboard, August 7, 1948, 89',
#  'Billboard, March 18, 1950, 90',
#  'Billboard, February 10, 1934, 11',
#  'Billboard, June 24, 1933, 16, 19',
#  'Billboard, October 15, 1932, 16',
#  "Billboard, May 31, 1930, 103 (VAUDEVILLE REVIEWS FROM COAST TO COAST: Keith's Franklin, N. Y.)",
#  'Billboard, April 18, 1936, 12',
#  'Billboard, March 6, 1937, 13 (Club Chatter)',
#  'Billboard, June 10, 1944, 46',
#  'Billboard, April 16, 1932, 9',
#  'Billboard, October 21, 1933, 11',
#  'The Billboard, Apr 4, 1936, 30',
#  'Billboard, September 19, 1942, page unknown',
#  'Billboard, January 4, 1930, 51',
#  'Billboard, April 15, 1933, 19',
#  'Billboard, July 19, 1947, 94',
#  'Billboard, May 13, 1939, 17',
#  'Billboard, April 17, 1937, 11',
#  'Billboard, January 7, 1950, 61',
#  'Billboard, February 29, 1936, 11 (NIGHT CLUB REVIEWS: Showboat, Jacksonville, Fla.)',
#  'Billboard, April 26, 1947, 96',
#  "Billboard, November 11, 1933, 11 (Night Spots-Gardens: 'ROUND THE TABLES)",
#  'Billboard, December 5, 1942, 14',
#  'Billboard, October 9, 1948, 85',
#  'Billboard, November 14, 1931, 9',
#  'Billboard, August 2, 1947, 42',
#  'Billboard, February 20, 1937, 1 [or 31, 34?]',
#  'Billboard, June 30, 1934, 11 (Round the Tables)',
#  'Billboard, February 15, 1936, page unknown (Route Department)',
#  'Billboard, January 16, 1937, 13 (Club Chatter)',
#  'Billboard, May 31, 1930, 16 (Vaudeville Reviews: The Palace, New York)',
#  "Billboard, August 29, 1931, 10 (Vaudeville Reviews: Loew's State, New York)",
#  'Billboard, November 17, 1934, 12',
#  'Billboard, February 8, 1936, page unknown (Route Department)',
#  'Billboard, June 12, 1948, 90',
#  'Billboard, January 22, 1938, 6 (Club Talent)',
#  'Billboard, February 11, 1933, 15',
#  'Billboard, January 31, 1942, page unknown',
#  'Billboard, July 3, 1948, 40',
#  'Billboard, October 29, 1949, 93',
#  'Billboard, October 10, 1936, 12',
#  'Billboard, March 16, 1935, 4',
#  'Billboard, July 5, 1930, 2 [or 13, 51?]',
#  'Billboard, July 13, 1940, 18 (Night clubs-vaudeville: Battle Creek Club Spends)',
#  'Billboard, August 25, 1934, 21',
#  'Billboard, August 27, 1932, 20',
#  'Billboard, August 13, 1938, 16',
#  'Billboard, November 1, 1930, 32',
#  'Billboard, February 18, 1950, 85',
#  'Billboard, June 28, 1947, 42',
#  'Billboard, November 21, 1936, 13',
#  'Billboard, March 15, 1930, 51',
#  'Billboard, August 23, 1947, 96',
#  'Billboard, May 28, 1949, 96',
#  'Billboard, January 21, 1950, 85',
#  'Billboard, June 11, 1949, 87',
#  'Billboard, July 30, 1938 (Route Department)',
#  'Billboard, September 11, 1937, 14',
#  'Billboard, September 27, 1930, 14',
#  'Billboard, April 30, 1938 (Route Department)',
#  'Billboard, August 7, 1948, 38',
#  'Billboard, October 18, 1947, 84',
#  'Billboard, April 23, 1938 (Route Department)',
#  'Billboard, June 14, 1947, 44',
#  'Billboard, December 4, 1948, 73',
#  'Billboard, April 25, 1942, page unknown',
#  'Billboard, May 7, 1938 (Route Department)',
#  'Billboard, April 27, 1935, 14',
#  'Billboard, May 29, 1948, 107',
#  'Billboard, October 30, 1937, 15 (Club Chatter)',
#  'Billboard, May 28, 1949, 75',
#  'Billboard, September 26, 1936, 16',
#  'Billboard, November 16, 1946, 36',
#  'Billboard, December 31, 1949, 58',
#  'Billboard, February 25, 1950, 86',
#  'Billboard, March 26, 1938, 19',
#  'Billboard, March 20, 1937, 13',
#  'Billboard, February 14, 1931, 19',
#  'Billboard, March 20, 1948, 84',
#  'Billboard, February 17, 1934, 11',
#  'Billboard, July 23, 1932, 5, 19 (General News: Chicago Chat)',
#  'Billboard, January 31, 1948, 77',
#  'Billboard, August 5, 1950, page unknown',
#  'Billboard, July 18, 1936, 19, 27 (Club Chatter)',
#  'Billboard, April 11, 1936, page unknown (Route Department)',
#  'Billboard, August 3, 1946, page unknown',
#  'Billboard, December 5, 1936, 28',
#  'Billboard, November 14, 1942, page unknown',
#  'Billboard, July 3, 1948, 91',
#  'Billboard, April 12, 1947, 89',
#  'Billboard, March 29, 1947, 136',
#  'Billboard, November 27, 1948, 135 (Circuses: DRESSING ROOM GOSSIP - Kansas City Shrine)',
#  'Billboard, December 11, 1937, 23',
#  'Billboard, March 28, 1936, 34',
#  "Billboard, March 12, 1938, 23 (Reviews of Units: Sollie Child's Parisian Follies Unit Case)",
#  'Billboard, June 4, 1938, 16',
#  'Billboard, September 25, 1948, 83',
#  'Billboard, September 17, 1938, 49 (Shorts)',
#  'Billboard, April 13, 1935, 14',
#  'Billboard, February 1, 1930, 56',
#  "Billboard, November 3, 1928, 17 (Last Half Reviews: Proctor's 86th St.)",
#  'Billboard, February 13, 1937 (Night Spots-Orchestra-Music: Female Imps Back in Philly)',
#  'Billboard, June 12, 1948, 66',
#  'Billboard, December 24, 1949, 73',
#  'Billboard, December 19, 1936, 31',
#  'Billboard, May 8, 1948, 97',
#  'Billboard, October 24, 1936, 27 (Possibilities)',
#  'Billboard, October 7, 1950, 20-21 (VAUDEVILLE REVIEWS - Capitol, New York)',
#  'Billboard, September 20, 1947, 72',
#  'Billboard, February 20, 1937, 13',
#  'Billboard, August 12, 1933, 11',
#  'Billboard, November 13, 1937, 25 (Halloween a Mop Up for Seattle)',
#  'Billboard, March 30, 1935, 13',
#  'Billboard, October 26, 1935, 15',
#  'Billboard, November 13, 1937, 22',
#  'Billboard, April 20, 1935, 14',
#  'Billboard, February 10, 1934, 10',
#  'Billboard, July 22, 1933, 16, 53',
#  'Billboard, August 30, 1930, 33 (1031952543)',
#  'Billboard, June 19, 1948, 30 (Uno)',
#  'Billboard, May 29, 1937 (Route Department)',
#  'Billboard, June 7, 1947, 40',
#  'Billboard, June 10, 1933, 16',
#  'Billboard, July 20, 1929, 44',
#  'Billboard, January 3, 1948, 70',
#  'Billboard, January 15, 1938, 39',
#  'Billboard, March 1, 1930, 94 (1031960405)',
#  'Billboard, July 5, 1930, 12 (Vaudeville Exploitation)',
#  'Billboard, August 28, 1937, 16 (Club Chatter)',
#  'Billboard, June 20, 1931, 11',
#  'Billboard, March 27, 1948, 134',
#  'Billboard, April 22, 1950, page unknown',
#  'Billboard, February 19, 1938, 21 (Club Talent)',
#  'The Billboard, Apr 25, 1936, 34',
#  'Billboard, February 17, 1945, 27 (Vaudeville Reviews: Oriental, Chicago)',
#  'Billboard, December 24, 1932, 16',
#  'Billboard, July 13, 1935, 13',
#  'Billboard, December 13, 1947, 61',
#  'Billboard, March 8, 1947, 88',
#  'Billboard, July 6, 1935, 46',
#  'Billboard, January 30, 1937, 13',
#  'Billboard, June 19, 1948, 25',
#  'The Billboard, May 9, 1936, 33',
#  'Billboard, April 5, 1947, 88',
#  "Billboard, September 2, 1933, 8 (Vaudeville Reviews: Loew's Orpheum, N. Y.)",
#  'Billboard, January 10, 1948, page unknown',
#  'Billboard, November 26, 1932, 16',
#  "Billboard, October 17, 1936, 16 (Vaudeville Reviews: Loew's State, New York)",
#  'Billboard, July 2, 1949, 52 (Uno)',
#  'Billboard, April 10, 1948, 90',
#  'Billboard, September 27, 1947, 43 (Uno)',
#  'Billboard, January 17, 1948, 39',
#  'Billboard, August 29, 1936, 15 (Club Chatter)',
#  'Billboard, September 4, 1937, 15',
#  'Billboard, September 21, 1935, 14',
#  'Billboard, May 8, 1937 (Route Department)',
#  'Billboard, April 24, 1948, 90',
#  'Billboard, January 24, 1948, 57',
#  'Billboard, June 5, 1937, 14 (Club Chatter)',
#  'Billboard, March 25, 1950, 94',
#  'Billboard, March 4, 1933, 5',
#  'Billboard, March 1, 1930, 51',
#  'Billboard, September 27, 1947, 87',
#  'Billboard, February 27, 1937, 13',
#  'Billboard, October 30, 1937 (Route Department)',
#  'Billboard, February 29, 1936, page unknown (Route Department)',
#  'Billboard, June 29, 1935, 15 (Vaudeville Reviews: Paris Programs)',
#  'Billboard, January 28, 1950, 80',
#  'Billboard, November 6, 1937 (Route Department)',
#  'Billboard, May 15, 1937 (Route Department)',
#  'Billboard, March 11, 1950, 97',
#  'Billboard, June 5, 1920, 30',
#  'Billboard, January 25, 1930, 49',
#  'Billboard, December 11, 1948, 75',
#  'Billboard, August 29, 1936, 1',
#  'Billboard, July 24, 1948, 39 (Uno)',
#  'Billboard, November 11, 1933, 26 (Editorial: Chicago Chat Green)',
#  "Billboard, August 22, 1931, 10 (Vaudeville Reviews: Loew's State, New York)",
#  'Billboard, December 20, 1947, page unknown',
#  'Billboard, March 21, 1936, page unknown (Route Department)',
#  'Billboard, May 9, 1936, 11 (Club Richman Charged With Objectionable Show)',
#  'Billboard, July 25, 1936, 19',
#  'Billboard, April 17, 1937, 11 (Female Imps and Nudes in Philly)',
#  'Billboard, December 28, 1935, 42',
#  'Billboard, July 9, 1949, 126',
#  'Billboard, March 26, 1938, 21',
#  'Billboard, April 1, 1950, 95',
#  'Billboard, November 26, 1949, 130',
#  'Billboard, July 26, 1947, 93',
#  'Billboard, August 27, 1938, 57',
#  'Billboard, July 2, 1938, 16',
#  'Billboard, December 5, 1931, 14-15',
#  'Billboard, December 13, 1947, 47 (Uno)',
#  'Billboard, May 7, 1949, 60',
#  'Billboard, December 5, 1936, 13 (Club Chatter)',
#  'Billboard, March 7, 1936, page unknown (Route Department)',
#  'Billboard, October 31, 1936, 13',
#  'Billboard, January 10, 1948, 68',
#  'Billboard, May 9, 1942, page unknown',
#  'Billboard, October 22, 1949, 57',
#  'Billboard, April 16, 1938, 63',
#  'Billboard, August 20, 1938, 19',
#  'Billboard, January 28, 1950, 43',
#  'Billboard, September 14, 1929, 19 (Shannon and Company)',
#  'Billboard, March 15, 1941, 17 (Fem Mimics for Camden)',
#  'Billboard, June 22, 1935, 13',
#  'Billboard, January 18, 1947, page unknown',
#  'Billboard, February 22, 1936, page unknown (Route Department)',
#  'Billboard, March 5, 1932, 47',
#  'Billboard, June 5, 1948, 93',
#  'Billboard, December 19, 1908, 5',
#  'Billboard, February 21, 1931, 17',
#  'Billboard, July 18, 1936, 19 (Club Chatter)',
#  'Billboard, July 24, 1948, 89',
#  'Billboard, June 14, 1924, 12',
#  'Billboard, January 17, 1942, page unknown',
#  'Billboard, June 19, 1943, page unknown',
#  'Billboard, February 4, 1950, 78',
#  'Billboard, November 22, 1947, 79',
#  'The Billboard, Apr 18, 1936, 30',
#  'Billboard, January 1, 1938, 17',
#  'Billboard, May 7, 1932, 9 (VAUDE NOTES)',
#  'Billboard, May 11, 1935, 33',
#  'Billboard, October 4, 1947, 73',
#  'Billboard, December 18, 1937, 22, 25',
#  'Billboard, June 12, 1937, 14',
#  'Billboard, July 9, 1938, 16',
#  'Billboard, May 7, 1938, 20 (Club Talent)',
#  'Billboard, August 14, 1915, 30',
#  'Billboard, June 3, 1933, 15 (Night Clubs)',
#  'Billboard, January 24, 1948, page unknown',
#  'Billboard, June 17, 1939, 20 (C M. Litteljohn, "Night Club Reviews: Spinning Wheel, Seattle")',
#  'Billboard, April 25, 1936, 12 (Club Chatter)',
#  'Billboard, September 2, 1939, 18 (Club Talent)',
#  'Billboard, July 15, 1939, 18 (Club Talent)',
#  'Billboard, October 26, 1940, 21',
#  'Billboard, June 3, 1933, 15',
#  'Billboard, June 25, 1949, 64-65',
#  'Billboard, October 20, 1934, 12',
#  'Billboard, February 18, 1939, 19',
#  'Billboard, September 6, 1947, 86',
#  'Billboard, December 20, 1947, 72',
#  'Billboard, May 18, 1935, 13',
#  'Billboard, September 27, 1947, 60',
#  'Billboard, December 11, 1937, 24 (Club Talent)',
#  "Billboard, July 14, 1928, 19 (Units Shape Up As Season's Bet)",
#  'Billboard, September 18, 1948, 86',
#  'Billboard, May 9, 1936, 23',
#  'Billboard, December 3, 1949, 72',
#  'Billboard, June 15, 1946, page unknown',
#  'Billboard, May 21, 1949, 45 (Uno)',
#  'Billboard, November 8, 1947, 81',
#  'Billboard, November 17, 1934, 12 (Round the Tables)',
#  "Billboard, December 8, 1928, 19 (Last-Half Reviews: Loew's National, N. Y.)",
#  'Billboard, May 17, 1947, 91',
#  'Billboard, March 22, 1930, 11',
#  'Billboard, June 26, 1948, 91',
#  'Billboard, December 19, 1936, 13',
#  'Billboard, September 17, 1938, 49 (O. Tomato Festival Draws)',
#  'Billboard, March 26, 1949, 72',
#  'Billboard, April 2, 1938, 20',
#  'Billboard, July 5, 1947, 44',
#  'Billboard, March 1, 1947, 89',
#  'Billboard, December 17, 1949, 73',
#  'Billboard, April 8, 1933, 15',
#  'Billboard, August 27, 1938, 22',
#  'Billboard, September 26, 1936, 20',
#  'Billboard, January 31, 1948, 53',
#  'Billboard, October 18, 1947, 43 (Uno)',
#  'Billboard, August 28, 1948, 93',
#  'Billboard, October 3, 1936, 16',
#  'Billboard, April 13, 1940, 29',
#  'Billboard, September 25, 1948, 64',
#  'Billboard, December 26, 1936, 35',
#  'Billboard, March 2, 1935, 12',
#  'Billboard, July 2, 1949, 73',
#  'Billboard, July 24, 1948, 66',
#  'Billboard, October 19, 1929, 33 (Lestra La Mont)',
#  'Billboard, September 4, 1948, 66',
#  'Billboard, May 22, 1937, 14',
#  'Billboard, January 18, 1936, 27 (Burlesque: Burly Briefs)',
#  'Billboard, June 26, 1948, 41 (Uno)',
#  'Billboard, October 17, 1936, 12',
#  'Billboard, July 5, 1930, 12',
#  'Billboard, October 15, 1932, 16 (MUSIC-RADIO: Night Spots Open Season)',
#  'Billboard, February 22, 1947, 87',
#  'Billboard, March 6, 1937, 13',
#  'Billboard, September 28, 1946, 72 (Circuses: Dressing Room Gossip - Dailey Bros.)',
#  'Billboard, February 4, 1950, 91',
#  'Billboard, April 6, 1935, 13',
#  'Billboard, July 3, 1937, 14',
#  'Billboard, May 1, 1937, 14',
#  'Billboard, October 25, 1947, 94',
#  'Billboard, October 8, 1932, 22',
#  'Billboard, October 17, 1936, 13',
#  'Billboard, January 24, 1942, page unknown',
#  'Billboard, July 27, 1940, 23',
#  'Billboard, September 17, 1949, page unknown',
#  'The Billboard, Apr 11, 1936, 27',
#  'Billboard, November 6, 1937, 24',
#  'Billboard, November 29, 1947, 132',
#  'Billboard, November 22, 1930, 19',
#  'Billboard, December 20, 1924, 17',
#  'Billboard, March 22, 1947, 19',
#  'Billboard, October 2, 1937, 14 (Club Chatter)',
#  'Billboard, April 4, 1936, page unknown (Route Department)',
#  'Billboard, June 19, 1948, 77',
#  'Billboard, March 30, 1935, 4',
#  'Billboard, October 10, 1936, 16',
#  'Billboard, February 11, 1950, 83',
#  'Billboard, September 11, 1937, 14 (Club Chatter)',
#  'Billboard, April 19, 1947, 94',
#  'Billboard, December 15, 1928, 14 (Vaudeville Notes)',
#  'Billboard, March 20, 1937, 13 (Club Chatter)',
#  'The Billboard, May 2, 1936, 29',
#  'Billboard, November 27, 1948, 148',
#  'Billboard, December 10, 1949, 76']

# %%
b.get('https://www-proquest-com.proxy.library.nyu.edu/eima/publication/686483')

# %%
def get_current_data():
    try:
        return json.loads(Path('billboard-data.json').read_text())
    except FileNotFoundError:
        return {
            '_investigate': []
        }
    
def put_current_data(data):
    Path('billboard-data.json').write_text(json.dumps(data))
    
    
for issue in [x for x in billboards if '1930' in x or '1931' in x or '1932' in x or '1933' in x or '1934' in x or '1935' in x or '1936' in x or '1937' in x or '1938' in x or '1939' in x or '1940' in x]:
    issue = issue.split('(')[0].strip()
    
    skip_ahead = False
    data = get_current_data()
    
    print()
    print(issue)

    if issue in data['_investigate']:
        print('issue in investigation!')
        skip_ahead = True
        
    if not skip_ahead:
        print('moving ahead...')

        elements = [x.strip() for x in issue.split(',') if x != 'Billboard']
        if len(elements) == 3:
            try:
                month, day = elements[0].split(' ')
                year = elements[1]
                if int(year) < 1929 or int(year) > 1940:
                    print(f'---> skipping: date not within range ({year})')
                    skip_ahead = True
                    continue

                if skip_ahead:
                    continue

                page = elements[2]
                if '(' in page:
                    page = [x.strip() for x in page.split('(')][0]
                month_short = month[:3]

                if 'page unknown' in page:
                    data['_investigate'].append(issue)
                    print(f'---> skipping: unknown page')
                    put_current_data(data)
                    skip_ahead = True
                    continue

                if skip_ahead:
                    continue

                if not year in data:
                    data[year] = {}

                if not month in data[year]:
                    data[year][month] = {}

                if not day in data[year][month]:
                    data[year][month][day] = {}

                if not page in data[year][month][day]:
                    data[year][month][day][page] = None

                print(f'looking for {year}, {month}, {day}')
                try:
                    select = Select(b.find_element_by_id('yearSelected'))
                    select.select_by_visible_text(year)
                    time.sleep(2)
                except:
                    time.sleep(5)
                    select = Select(b.find_element_by_id('yearSelected'))
                    select.select_by_visible_text(year)
                    time.sleep(2)

                try:
                    select = Select(b.find_element_by_id('monthSelected'))
                    select.select_by_visible_text(month)
                    time.sleep(2)
                except:
                    time.sleep(5)
                    select = Select(b.find_element_by_id('monthSelected'))
                    select.select_by_visible_text(month)
                    time.sleep(2)

                select_issue = []
                try:
                    select = Select(b.find_element_by_id('issueSelected'))
                    select_issue = [x.text for x in select.options if f'{month_short} {day},' in x.text]
                except:
                    time.sleep(5)
                    select = Select(b.find_element_by_id('issueSelected'))
                    select_issue = [x.text for x in select.options if f'{month_short} {day},' in x.text]

                if len(select_issue) == 1:
                    select_issue = select_issue[0]
                elif len(select_issue) == 0:
                    data['_investigate'].append(issue)
                    print(f'---> skipping: unknown issue')
                    put_current_data(data)
                    skip_ahead = True
                    continue

                if skip_ahead:
                    continue
                select.select_by_visible_text(select_issue)
                time.sleep(1)
                b.find_element_by_css_selector('input[value="View issue"]').click()

                time.sleep(10)

                try:
                    b.find_element_by_css_selector('a[title="First page"]').click()
                    time.sleep(10)
                except:
                    if len([x.text for x in b.find_elements_by_css_selector('li.disabled') if 'First' in x.text]):
                        pass # we're already on the first page
                    else:
                        continue # skipping...

                done = False

                print(f'browsing for {page}')
                while not done:
                    if len({x.find_element_by_class_name('titleAuthorETC').text: x for x in b.find_elements_by_class_name('resultItem') if x.find_element_by_class_name('titleAuthorETC').text.endswith(': ' + page + '.')}):
                        done = True
                    else:
                        b.find_element_by_css_selector('a[title="Next page"]').click()
                        time.sleep(10)

                found = {x.find_element_by_class_name('titleAuthorETC').text: x for x in b.find_elements_by_class_name('resultItem') if x.find_element_by_class_name('titleAuthorETC').text.endswith(': ' + page + '.')}

                link = found[list(found.keys())[0]].find_elements_by_tag_name('a')[3].get_attribute('href')

                data[year][month][day][page] = link

                put_current_data(data)
            except Exception as e:
                print(issue, 'failed...', e)
                pass
        else:
            #print('-----> skipping because cannot interpret')
            #print(elements)
            continue # skipping
# Out:
# Billboard, June 21, 1930, 16
# issue in investigation!
#
# Billboard, March 28, 1936, page unknown
# issue in investigation!
#
# Billboard, January 27, 1930, 49
# issue in investigation!
#
# Billboard, August 1, 1936, 19
# issue in investigation!
#
# Billboard, November 19, 1938, 18
# issue in investigation!
#
# Billboard, September 10, 1932, 7
# issue in investigation!
#
# Billboard, August 31, 1935, 14
# issue in investigation!
#
# Billboard, May 29, 1937, 37
# issue in investigation!
#
# Billboard, May 14, 1938, 18
# issue in investigation!
#
# Billboard, December 5, 1936, 14
# issue in investigation!
#
# Billboard, January 27, 1940, page unknown
# issue in investigation!
#
# Billboard, June 7, 1930, 16
# issue in investigation!
#
# Billboard, January 1, 1938, 29
# issue in investigation!
#
# Billboard, September 4, 1937, 14
# issue in investigation!
#
# Billboard, March 17, 1937, 49
# issue in investigation!
#
# Billboard, January 22, 1938, 8
# issue in investigation!
#
# Billboard, March 8, 1930, 51
# issue in investigation!
#
# Billboard, January 19, 1935, 12
# issue in investigation!
# Billboard, April 2, 1938, 20
# issue in investigation!
#
# Billboard, April 8, 1933, 15
# issue in investigation!
#
# Billboard, August 27, 1938, 22
# issue in investigation!
#
# Billboard, September 26, 1936, 20
# issue in investigation!
#
# Billboard, October 3, 1936, 16
# issue in investigation!
#
# Billboard, April 13, 1940, 29
# issue in investigation!
#
# Billboard, December 26, 1936, 35
# issue in investigation!
#
# Billboard, March 2, 1935, 12
# issue in investigation!
#
# Billboard, May 22, 1937, 14
# issue in investigation!
#
# Billboard, January 18, 1936, 27
# issue in investigation!
#
# Billboard, October 17, 1936, 12
# issue in investigation!
#
# Billboard, July 5, 1930, 12
# issue in investigation!
#
# Billboard, October 15, 1932, 16
# issue in investigation!
#
# Billboard, March 6, 1937, 13
# moving ahead...
# looking for 1937, March, 6
# browsing for 13
#
# Billboard, April 6, 1935, 13
# issue in investigation!
#
# Billboard, July 3, 1937, 14
# issue in investigation!
#
# Billboard, May 1, 1937, 14
# issue in investigation!
#
# Billboard, October 8, 1932, 22
# issue in investigation!
#
# Billboard, October 17, 1936, 13
# issue in investigation!
#
# Billboard, July 27, 1940, 23
# issue in investigation!
#
# The Billboard, Apr 11, 1936, 27
# moving ahead...
#
# Billboard, November 6, 1937, 24
# issue in investigation!
#
# Billboard, November 22, 1930, 19
# issue in investigation!
#
# Billboard, October 2, 1937, 14
# issue in investigation!
#
# Billboard, April 4, 1936, page unknown
# issue in investigation!
#
# Billboard, March 30, 1935, 4
# issue in investigation!
#
# Billboard, October 10, 1936, 16
# issue in investigation!
#
# Billboard, September 11, 1937, 14
# issue in investigation!
#
# Billboard, March 20, 1937, 13
# moving ahead...
# looking for 1937, March, 20
# browsing for 13
#
# The Billboard, May 2, 1936, 29
# moving ahead...

# %%
get_current_data()
# Out:
# {'_investigate': ['Billboard, March 28, 1936, page unknown (Route Department)',
#   'Billboard, January 27, 1930, 49',
#   'Billboard, January 27, 1940, page unknown',
#   'Billboard, March 17, 1937, 49',
#   'Billboard, March 8, 1930, 51',
#   'Billboard, January 23, 1937, 13',
#   'Billboard, June 25, 1938, 17',
#   'Billboard, March 14, 1936, page unknown (Route Department)',
#   'Billboard, February 15, 1936, page unknown (Route Department)',
#   'Billboard, January 16, 1937, 13 (Club Chatter)',
#   'Billboard, February 8, 1936, page unknown (Route Department)',
#   'Billboard, August 25, 1934, 21',
#   'Billboard, August 27, 1932, 20',
#   'Billboard, February 17, 1934, 11',
#   'Billboard, April 11, 1936, page unknown (Route Department)',
#   'Billboard, August 1, 1936, 19 (Club Chatter)',
#   'Billboard, November 19, 1938, 18',
#   'Billboard, May 29, 1937, 37 (Club Chatter)',
#   'Billboard, May 14, 1938, 18',
#   'Billboard, November 17, 1934, 12',
#   'Billboard, November 30, 1935, 14',
#   'Billboard, November 29, 1930, 32',
#   'Billboard, August 8, 1936, 12',
#   'Billboard, September 10, 1932, 7 (Collier Returning to America)',
#   'Billboard, August 31, 1935, 14 (Round the Tables)',
#   'Billboard, December 5, 1936, 14 (Club Chatter)',
#   'Billboard, April 27, 1935, 14',
#   'Billboard, October 24, 1936, 27 (Possibilities)',
#   'Billboard, February 20, 1937, 13',
#   'Billboard, February 29, 1936, page unknown (Route Department)',
#   'Billboard, August 29, 1936, 1',
#   'Billboard, November 11, 1933, 26 (Editorial: Chicago Chat Green)',
#   'Billboard, March 21, 1936, page unknown (Route Department)',
#   'Billboard, May 9, 1936, 11 (Club Richman Charged With Objectionable Show)',
#   'Billboard, July 25, 1936, 19',
#   'Billboard, March 7, 1936, page unknown (Route Department)',
#   'Billboard, February 22, 1936, page unknown (Route Department)',
#   'Billboard, October 15, 1932, 16 (MUSIC-RADIO: Night Spots Open Season)',
#   'Billboard, April 4, 1936, page unknown (Route Department)',
#   'Billboard, August 13, 1938, 16',
#   'Billboard, November 1, 1930, 32',
#   'Billboard, November 21, 1936, 13',
#   'Billboard, September 26, 1936, 16',
#   'Billboard, October 26, 1940, 21',
#   'Billboard, December 19, 1936, 13',
#   'Billboard, September 17, 1938, 49 (O. Tomato Festival Draws)',
#   'Billboard, October 8, 1932, 22',
#   'Billboard, October 17, 1936, 13',
#   'Billboard, January 1, 1938, 29',
#   'Billboard, September 4, 1937, 14',
#   'Billboard, September 9, 1933, 11',
#   'Billboard, October 11, 1930, 31',
#   'Billboard, January 20, 1934, 6 (Vaudeville: Another All-Girl Revue)',
#   'Billboard, December 6, 1930, 22',
#   'Billboard, February 10, 1934, 11',
#   'Billboard, October 15, 1932, 16',
#   'Billboard, April 18, 1936, 12',
#   'Billboard, April 16, 1932, 9',
#   'Billboard, October 21, 1933, 11',
#   'Billboard, January 4, 1930, 51',
#   'Billboard, April 15, 1933, 19',
#   'Billboard, May 13, 1939, 17',
#   'Billboard, April 17, 1937, 11',
#   "Billboard, November 11, 1933, 11 (Night Spots-Gardens: 'ROUND THE TABLES)",
#   'Billboard, November 14, 1931, 9',
#   'Billboard, June 30, 1934, 11 (Round the Tables)',
#   'Billboard, January 22, 1938, 6 (Club Talent)',
#   'Billboard, February 11, 1933, 15',
#   'Billboard, October 10, 1936, 12',
#   'Billboard, March 16, 1935, 4',
#   'Billboard, July 13, 1940, 18 (Night clubs-vaudeville: Battle Creek Club Spends)',
#   'Billboard, March 15, 1930, 51',
#   'Billboard, September 11, 1937, 14',
#   'Billboard, September 27, 1930, 14',
#   'Billboard, October 30, 1937, 15 (Club Chatter)',
#   'Billboard, March 26, 1938, 19',
#   'Billboard, February 14, 1931, 19',
#   'Billboard, December 5, 1936, 28',
#   'Billboard, December 11, 1937, 23',
#   'Billboard, March 28, 1936, 34',
#   "Billboard, March 12, 1938, 23 (Reviews of Units: Sollie Child's Parisian Follies Unit Case)",
#   'Billboard, June 4, 1938, 16',
#   'Billboard, September 17, 1938, 49 (Shorts)',
#   'Billboard, April 13, 1935, 14',
#   'Billboard, February 1, 1930, 56',
#   'Billboard, December 19, 1936, 31',
#   'Billboard, August 12, 1933, 11',
#   'Billboard, November 13, 1937, 25 (Halloween a Mop Up for Seattle)',
#   'Billboard, March 30, 1935, 13',
#   'Billboard, October 26, 1935, 15',
#   'Billboard, November 13, 1937, 22',
#   'Billboard, April 20, 1935, 14',
#   'Billboard, February 10, 1934, 10',
#   'Billboard, August 30, 1930, 33 (1031952543)',
#   'Billboard, June 10, 1933, 16',
#   'Billboard, January 15, 1938, 39',
#   'Billboard, March 1, 1930, 94 (1031960405)',
#   'Billboard, July 5, 1930, 12 (Vaudeville Exploitation)',
#   'Billboard, August 28, 1937, 16 (Club Chatter)',
#   'Billboard, June 20, 1931, 11',
#   'Billboard, February 19, 1938, 21 (Club Talent)',
#   'Billboard, December 24, 1932, 16',
#   'Billboard, July 13, 1935, 13',
#   'Billboard, July 6, 1935, 46',
#   'Billboard, January 30, 1937, 13',
#   'Billboard, November 26, 1932, 16',
#   'Billboard, August 29, 1936, 15 (Club Chatter)',
#   'Billboard, September 4, 1937, 15',
#   'Billboard, September 21, 1935, 14',
#   'Billboard, June 5, 1937, 14 (Club Chatter)',
#   'Billboard, March 4, 1933, 5',
#   'Billboard, March 1, 1930, 51',
#   'Billboard, February 27, 1937, 13',
#   'Billboard, June 29, 1935, 15 (Vaudeville Reviews: Paris Programs)',
#   'Billboard, January 25, 1930, 49',
#   'Billboard, April 17, 1937, 11 (Female Imps and Nudes in Philly)',
#   'Billboard, December 28, 1935, 42',
#   'Billboard, March 26, 1938, 21',
#   'Billboard, August 27, 1938, 57',
#   'Billboard, July 2, 1938, 16',
#   'Billboard, December 5, 1931, 14-15',
#   'Billboard, December 5, 1936, 13 (Club Chatter)',
#   'Billboard, October 31, 1936, 13',
#   'Billboard, April 16, 1938, 63',
#   'Billboard, August 20, 1938, 19',
#   'Billboard, June 22, 1935, 13',
#   'Billboard, March 5, 1932, 47',
#   'Billboard, February 21, 1931, 17',
#   'Billboard, July 18, 1936, 19 (Club Chatter)',
#   'Billboard, January 1, 1938, 17',
#   'Billboard, May 7, 1932, 9 (VAUDE NOTES)',
#   'Billboard, May 11, 1935, 33',
#   'Billboard, June 12, 1937, 14',
#   'Billboard, July 9, 1938, 16',
#   'Billboard, May 7, 1938, 20 (Club Talent)',
#   'Billboard, June 3, 1933, 15 (Night Clubs)',
#   'Billboard, April 25, 1936, 12 (Club Chatter)',
#   'Billboard, September 2, 1939, 18 (Club Talent)',
#   'Billboard, July 15, 1939, 18 (Club Talent)',
#   'Billboard, June 3, 1933, 15',
#   'Billboard, October 20, 1934, 12',
#   'Billboard, February 18, 1939, 19',
#   'Billboard, May 18, 1935, 13',
#   'Billboard, December 11, 1937, 24 (Club Talent)',
#   'Billboard, May 9, 1936, 23',
#   'Billboard, November 17, 1934, 12 (Round the Tables)',
#   'Billboard, March 22, 1930, 11',
#   'Billboard, April 2, 1938, 20',
#   'Billboard, April 8, 1933, 15',
#   'Billboard, August 27, 1938, 22',
#   'Billboard, September 26, 1936, 20',
#   'Billboard, October 3, 1936, 16',
#   'Billboard, April 13, 1940, 29',
#   'Billboard, December 26, 1936, 35',
#   'Billboard, March 2, 1935, 12',
#   'Billboard, May 22, 1937, 14',
#   'Billboard, January 18, 1936, 27 (Burlesque: Burly Briefs)',
#   'Billboard, October 17, 1936, 12',
#   'Billboard, July 5, 1930, 12',
#   'Billboard, April 6, 1935, 13',
#   'Billboard, July 3, 1937, 14',
#   'Billboard, May 1, 1937, 14',
#   'Billboard, July 27, 1940, 23',
#   'Billboard, November 6, 1937, 24',
#   'Billboard, November 22, 1930, 19',
#   'Billboard, October 2, 1937, 14 (Club Chatter)',
#   'Billboard, March 30, 1935, 4',
#   'Billboard, October 10, 1936, 16',
#   'Billboard, September 11, 1937, 14 (Club Chatter)',
#   'Billboard, June 21, 1930, 16',
#   'Billboard, March 28, 1936, page unknown',
#   'Billboard, August 1, 1936, 19',
#   'Billboard, September 10, 1932, 7',
#   'Billboard, August 31, 1935, 14',
#   'Billboard, May 29, 1937, 37',
#   'Billboard, December 5, 1936, 14',
#   'Billboard, June 7, 1930, 16',
#   'Billboard, January 22, 1938, 8',
#   'Billboard, January 19, 1935, 12',
#   'Billboard, January 20, 1934, 6',
#   'Billboard, March 14, 1936, page unknown',
#   'Billboard, May 31, 1930, 103',
#   'Billboard, February 29, 1936, 11',
#   'Billboard, November 11, 1933, 11',
#   'Billboard, June 30, 1934, 11',
#   'Billboard, February 15, 1936, page unknown',
#   'Billboard, January 16, 1937, 13',
#   'Billboard, May 31, 1930, 16',
#   'Billboard, August 29, 1931, 10',
#   'Billboard, February 8, 1936, page unknown',
#   'Billboard, January 22, 1938, 6',
#   'Billboard, July 13, 1940, 18',
#   'Billboard, October 30, 1937, 15',
#   'Billboard, April 11, 1936, page unknown',
#   'Billboard, March 12, 1938, 23',
#   'Billboard, September 17, 1938, 49',
#   'Billboard, October 24, 1936, 27',
#   'Billboard, November 13, 1937, 25',
#   'Billboard, August 30, 1930, 33',
#   'Billboard, March 1, 1930, 94',
#   'Billboard, August 28, 1937, 16',
#   'Billboard, February 19, 1938, 21',
#   'Billboard, September 2, 1933, 8',
#   'Billboard, October 17, 1936, 16',
#   'Billboard, August 29, 1936, 15',
#   'Billboard, June 5, 1937, 14',
#   'Billboard, February 29, 1936, page unknown',
#   'Billboard, June 29, 1935, 15',
#   'Billboard, November 11, 1933, 26',
#   'Billboard, August 22, 1931, 10',
#   'Billboard, March 21, 1936, page unknown',
#   'Billboard, May 9, 1936, 11',
#   'Billboard, December 5, 1936, 13',
#   'Billboard, March 7, 1936, page unknown',
#   'Billboard, February 22, 1936, page unknown',
#   'Billboard, July 18, 1936, 19',
#   'Billboard, May 7, 1932, 9',
#   'Billboard, May 7, 1938, 20',
#   'Billboard, June 17, 1939, 20',
#   'Billboard, April 25, 1936, 12',
#   'Billboard, September 2, 1939, 18',
#   'Billboard, July 15, 1939, 18',
#   'Billboard, December 11, 1937, 24',
#   'Billboard, January 18, 1936, 27',
#   'Billboard, October 2, 1937, 14',
#   'Billboard, April 4, 1936, page unknown'],
#  '1930': {'January': {'27': {'49': None},
#    '4': {'51': 'https://www-proquest-com.proxy.library.nyu.edu/eima/docview/
 'https://www-proquest-com.proxy.library.nyu.edu/eima/docview/1032223800/DF3BDE8CC5D34CD2PQ/175?accountid=12768'}},
#   'April': {'13': {'29': 'https://www-proquest-com.proxy.library.nyu.edu/eima/docview/1032212641/E7B675F8DCB84592PQ/191?accountid=12768'}}}}

# %%
def get_current_afro_american_data():
    try:
        return json.loads(Path('afro-american-data.json').read_text())
    except FileNotFoundError:
        return {
            '_investigate': []
        }
    
def put_current_afro_american_data(data):
    Path('afro-american-data.json').write_text(json.dumps(data))
    
    
get_current_afro_american_data()
# Out:
# {'_investigate': []}

# %%
for issue in [x for x in afroamericans if '1930' in x or '1931' in x or '1932' in x or '1933' in x or '1934' in x or '1935' in x or '1936' in x or '1937' in x or '1938' in x or '1939' in x or '1940' in x]:
    issue = issue.split('(')[0].strip()
    print(issue)
    
    if issue in data['_investigate']:
        print('issue in investigation!')
        skip_ahead = True
        
    if not skip_ahead:
        print('moving ahead...')

        elements = [x.strip() for x in issue.split(',') if x != 'Billboard']
        if len(elements) == 3:
            try:
                month, day = elements[0].split(' ')
                year = elements[1]

                page = elements[2]
                if '(' in page:
                    page = [x.strip() for x in page.split('(')][0]
                month_short = month[:3]

                if 'page unknown' in page:
                    data['_investigate'].append(issue)
                    print(f'---> skipping: unknown page')
                    put_current_data(data)
                    skip_ahead = True
                    continue

                if skip_ahead:
                    continue

                if not year in data:
                    data[year] = {}

                if not month in data[year]:
                    data[year][month] = {}

                if not day in data[year][month]:
                    data[year][month][day] = {}

                if not page in data[year][month][day]:
                    data[year][month][day][page] = None

                print(f'looking for {year}, {month}, {day}')
            except:
                pass
# Out:
# Baltimore Afro-American, October 5, 1935, 16
# moving ahead...
# Baltimore Afro-American, October 20, 1934, 13
# moving ahead...
# Baltimore Afro-American, April 2, 1932, 3
# moving ahead...
# Baltimore Afro-American, April 4, 1936, 18
# moving ahead...
# Baltimore Afro-American, July 6, 1935, 9
# moving ahead...
# Baltimore Afro-American, October 8, 1938, 11
# moving ahead...
# Baltimore Afro-American, September 29, 1934, 12
# moving ahead...
# Baltimore Afro-American, December 24, 1932, 18
# moving ahead...
# Baltimore Afro-American, December 31, 1938, 3
# moving ahead...
# Baltimore Afro-American, October 1, 1938, 11
# moving ahead...
# Baltimore Afro-American, October 6, 1934, 7
# moving ahead...
# Baltimore Afro-American, April 9, 1932, 8
# moving ahead...
# Baltimore Afro-American, February 8, 1930, 1
# moving ahead...
# Baltimore Afro-American, December 1, 1934, 8
# moving ahead...
# Baltimore Afro-American, April 6, 1935, 8
# moving ahead...
# Baltimore Afro-American, December 15, 1934, 9
# moving ahead...
# Baltimore Afro-American, August 18, 1934, 11
# moving ahead...
# Baltimore Afro-American, December 31, 1938, 7
# moving ahead...
# Baltimore Afro-American, November 23, 1940, 12
# moving ahead...
# Baltimore Afro-American, January 12, 1935, 9
# moving ahead...
# Baltimore Afro-American, October 24, 1931, 5
# moving ahead...
# Baltimore Afro-American, October 5, 1935, 16
# moving ahead...
# Baltimore Afro-American, March 28, 1936, 13
# moving ahead...
# Baltimore Afro-American, December 13, 1930, 7
# moving ahead...
# Baltimore Afro-American, November 22, 1930, 8
# moving ahead...
# Baltimore Afro-American, January 28, 1933, 1
# moving ahead...
