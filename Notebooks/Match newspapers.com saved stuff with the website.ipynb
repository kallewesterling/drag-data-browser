# %%
from selenium import webdriver
from time import sleep
from pathlib import Path
import slugify, json

# %%
try:
    b
except:
    b = webdriver.Firefox()

# %%
all_newspapers = ['Brooklyn Life and Activities of Long Island Society', 'Bradford Evening Star and The Bradford Daily Record', 'The Ventura County Star and the Ventura Daily Post', 'Hamburg Sun and the Erie County Independent', 'Gloversville and Johnstown Morning Herald', 'Baldwinsville Gazette and Farmers Journal', 'Camden Morning Post', 'Rochester Democrat and Chronicle', 'Richmond Palladium and Sun-Telegram', 'Pottsville Republican and Herald', 'Chillicothe Constitution-Tribune', 'Statesville Record And Landmark', 'Los Angeles Illustrated Daily News', 'Hutchinson News', 'Colorado Springs Gazette Telegraph', 'Central New Jersey Daily Home News', 'Petaluma Daily Morning Courier', 'Binghamton Press and Sun-Bulletin', 'Orangeburg Times and Democrat', 'Massillon Evening Independent', 'Los Angeles Evening Citizen News', 'Harlingen Valley Morning Star', 'Haleyville Advertiser-Journal', 'East Liverpool Evening Review', 'Decatur Wise County Messenger', 'Alton Illinois Evening Telegraph', 'Yuba City Independent-Herald', 'Springfield Leader and Press', 'New Philadelphia Daily Times', 'Monongahela Daily Republican', 'Lowville Journal and Republican', 'Los Angeles Evening Post-Record', 'Klamath Falls Evening Herald', 'Benton Harbor News-Palladium', 'Local News Items, Kenosha News', 'Corpus Christi Caller-Times', 'Chambersburg Public Opinion', 'Canandaigua Daily Messenger', 'Uniontown Evening Standard', 'Pittsfield Berkshire Eagle', 'Milwaukee Jewish Chronicle', 'Louisville Courier-Journal', 'Grass Valley Morning Union', 'Edwardsville Intelligencer', 'Zanesville Times Recorder', 'White Plains Journal News', 'The Bristol Daily Courier', 'Syracuse Daily Post-Standard', 'Stroudsburg Pocono Record', 'Seminole Evening Reporter', 'Saint Joseph Herald-Press', 'Raleigh News and Observer', 'North Tonawanda Evening News', 'Nashville Daily News-Journal', 'Lubbock Morning Avalanche', 'Lubbock Avalanche-Journal', 'Hazleton Standard-Speaker', 'Harrisburg Sunday Courier', 'Hagerstown Morning Herald', 'Greenfield Daily Reporter', 'Elyria Chronicle-Telegram', 'Davenport Quad-City Times', 'Central New Jersey Home News', 'Verona-Cedar Grove Times', 'Uniontown Morning Herald', 'Spokane Spokesman-Review', 'Sioux-Falls Argus-Leader', 'Pomona Progress Bulletin', 'Newport News Daily Press', 'Montpelier Evening Argus', 'Monnessin Daily Independent', 'McKinney Courier-Gazette', 'Lubbock Avalance-Journal', 'Long Branch Daily Record', 'Janesville Daily Gazette', 'Fort Worth Star-Telegram', 'Dunkirk Evening Observer', 'Cumberland Evening Times', 'Cleveland-Co. Democrat-News', 'Brooklyn Home Talk the Item', 'Bridgewater Courier-News', 'Bakersfield Morning Echo', 'Wisconsin Jewish Chronicle', 'Wilmington News-Journal', 'Wilmington Morning Star', 'Wilmington Morning News', 'Washington Evening Star', 'South Florida Sun Sentinel', 'Sikeston Daily Standard', 'Salem Statesman Journal', 'Port Chester Daily Item', 'Ogden Standard-Examiner', 'Newark Jewish Chronicle', 'Middletown Times Herald', 'Middletown Daily Herald', 'Marysville Journal-Tribune', 'Lancaster Eagle-Gazette', 'Harrisburg Evening News', 'Green Bay Press-Gazette', 'Chicago Suburban Economist', 'Big Spring Daily Herald', 'Amsterdam Evening Recorder', 'Wilkes-Barre Times Leader', 'Washington Sunday Star', 'Vineland Daily Journal', 'The Bristol News Bulletin', 'Shamokin News-Dispatch', 'Scranton Times-Tribune', 'Rhinelander Daily News', 'Reno Nevada State Journal', 'Petaluma Argus-Courier', 'Meramec Valley Transcript', 'Mansfield News-Journal', 'Mansfield News Journal', 'Long Beach Press-Telegram', 'Lake Geneva Regional News', 'Kingston Daily Freeman', 'Jamestown Evening Journal', 'Jackson Clarion-Ledger', 'Idaho Falls Post-Register', 'Hermitage, Missouri Index', 'Hazleton Plain Speaker', 'Greenville Daily Advocate', 'Bluefield Daily Telegraph', 'Austin American-Statesman', 'Appleton Post-Crescent', 'Allentown Morning Call', 'Yonkers Herald Statesman', 'Stevens Point Journal', 'St. Louis Star and Times', 'St. Louis Globe-Democrat', 'Santa Rosa Republican', 'Ridgewood Sunday News', 'Pomona Progress Bulletin', 'Pittsburgh Sun-Telegraph', 'Paterson Morning Call', 'Montgomery Advertiser', 'Moberly Monitor-Index', 'Madison Capital Times', 'Long Island Star-Journal', 'Glens-Falls Post-Star', 'Glens Falls Post-Star', 'El Nuevo Miami Herald', 'Dunkirk Evening Observer', 'Davenport Daily Times', 'Cushing Daily Citizen', 'Arlington Heights Herald', 'Wisconsin State Journal', 'Utica Observer-Dispatch', 'Tyler Morning Telegraph', 'The Selma Times-Journal', 'Sunday Journal and Star', 'St. Louis Post-Dispatch', 'Salinas Morning Post', 'Rutland Daily Herald', 'Richmond Times-Dispatch', 'Richmond Times Dispatch', 'Richmond Palladium-Item', 'Racine Journal-Times', 'Racine Journal Times', 'Poughkeepsie Eagle-News', 'Poughkeepsie Eagle News', 'Plattsburgh Daily Press', 'Pittsburgh Post-Gazette', 'Panama City News-Herald', 'Oshkosh Northwestern', 'New York Herald Tribune', 'New York Amsterdam News', 'Muncie Evening Press', 'Lumberton Robesonian', 'Long Island Daily Press', 'Knoxville News-Sentinel', 'Johnson City Staff-News', 'Ironwood Daily Globe', 'Hayward Daily Review', 'Harrisburg Telegraph', 'Franklin News-Herald', 'Fort Collins Coloradoan', 'El Paso Evening Post', 'Dover Daily Reporter', 'Dixon Evening Telegraph', 'Decatur Daily Review', 'Cleveland Call and Post', 'Chattanooga Daily Times', 'Cedar Rapids Gazette', 'Buffalo Courier-Express', 'Brooklyn Standard Union', 'Brattleboro Reformer', 'Baltimore Afro-American', 'Bakersfield Californian', 'Alexandria Town Talk', 'Akron Beacon Journal', 'Tonawanda Evening News', 'Syracuse Post-Standard', 'Shamokin News-Disp
Sun', 'Jackson Sun', 'Ithaca Journal', 'Herald-Journal', 'Helper Journal', 'Gaffney Ledger', 'Evening Review', 'Eunice News', 'Daily Register', 'Cache American', 'Butte Miner', 'Bryan Eagle', 'Berwyn Life', 'Aiken Standard', 'Whittier News', 'Vancouver Sun', 'Troy Times', 'Theatre World', 'Tampa Tribune', 'Salem News', 'Richmond Item', 'Pinedale ?', 'Phoenix Index', 'Paris News', 'Oklahoma News', 'New York Post', 'Miami Tribune', 'Lowell Sun', 'Las Vegas Age', 'Journal Times', 'Chicago World', 'Buffalo Times', 'Brooklyn Life', 'Brooklyn Chat', 'Baltimore Sun', 'Anniston Star', 'Windsor Star', 'Times Record', 'Times Herald', 'Sun-Advocate', 'Student Life', 'Star Tribune', 'News Tribune', 'New York Sun', 'New York Age', 'Morning Post', 'Morning News', 'Morning Call', 'Miami Herald', 'Lincoln Star', 'Lima News', 'Kenosha News', 'Journal News', 'Jet Magazine', 'Herald-Press', 'Evening News', 'Dothan Eagle', 'Daily Record', 'Boston Globe', 'Times Union', 'Tampa Times', 'News-Herald', 'Evening Sun', 'Californian', 'Tennessean', 'Star Press', 'Saratogian', 'Miami News', 'Fresno Bee']

# %%
def drop(lst, removables):
    for item in removables:
        try:
            lst.remove(item)
        except:
            pass
    return lst
            
if not Path('papers').exists():
    Path('papers').mkdir(parents=True)

skip = False

all_newspapers = drop(all_newspapers, ['Dispatch', 'Daily Times', 'Daily News', 'Davenport Democrat', 'Cohoes American', 'Chicago Sunday Tribune'])

for newspaper in all_newspapers:
    if skip:
        continue
    if newspaper in ['Albany Times-Union',
                     'Albany Times-Union, date unknown',
                     'Baltimore Afro-American',
                     'all_boy_revue also in The Morning Post',
                     'Amsterdam Evening Recorder',
                     'Back Stage',
                     'Baldwinsville Gazette and Farmers Journal',
                     'Berwyn Life October 9',
                     'Bob Murphy, \'Private Lives\' Is Next Offering at Edyth Bush, Star Tribune',
                     'Bay Area Reporter',
                     'Billboard',
                     'Broadway Tattler',
                     'Chicago Economist',
                     'Courier',
                     'Chicago Defender',
                     'Cleveland Call and Post',
                     'CSGT ??? ILL should be requested',
                     'Gloversville and Johnstown Morning Herald',
                     'Hamburg Sun and the Erie County Independent',
                     'Richmond Palladium and Sun-Telegram',
                     'Central New Jersey Daily Home News',
                     'Los Angeles Illustrated Daily News',
                     'Lowville Journal and Republican',
                     'Chambersburg Public Opinion',
                     'North Tonawanda Evening News',
                     'Syracuse Daily Post-Standard',
                     'Spokane Spokesman-Review',
                     'Local News Items, Kenosha News',

                    ]:
        continue
    
    replacements = {
        'Alexandria Town Talk': 'The Town Talk',
        'Bradenton FL Herald': 'The Bradenton Herald',
        'Brooklyn Eagle': 'The Brooklyn Daily Eagle',
        'Brooklyn Times Union': 'Times Union',
        'Cedar Rapids Gazette': 'The Gazette',
        'Dover Daily Reporter': 'The Daily Reporter',
        'Elyria Chronicle-Telegram': 'The Chronicle-Telegram',
        'Haleyville Advertiser-Journal': 'The Advertiser-Journal',
        'Chambersburg Public Opinion': 'Public Opinion',
        'Pittsfield Berkshire Eagle': 'The Berkshire Eagle',
        'Wilkes-Barre Times Leader': 'The Times Leader'
    }
    
    
    print(newspaper)
    datafile = 'papers/' + slugify.slugify(newspaper) + '.json'
    if not Path(datafile).exists():
        try:
            b.get('http://www.apple.com')
            sleep(2)
            b.get(f'https://www.newspapers.com/papers/#containing={newspaper}')
            sleep(3)
        except:
            try:
                b.get('http://www.apple.com')
                sleep(1)
                b.get(f'https://www.newspapers.com/papers/#containing={newspaper}')
                sleep(3)
            except:
                continue

        if len(b.find_elements_by_css_selector('.record-result')) > 1:
            for s, r in replacements.items():
                if newspaper == s:
                    newspaper = r

            search = [x for x in b.find_elements_by_css_selector('.record-result') if  x.find_elements_by_tag_name('a')[1].text == newspaper]
            found = False
            if len(search) == 1 or len(search) == 2:
                result = [x for x in b.find_elements_by_css_selector('.record-result') if  x.find_elements_by_tag_name('a')[1].text == newspaper][0]
                found = True
            else:
                search = [x for x in b.find_elements_by_css_selector('.record-result') if  x.find_elements_by_tag_name('a')[1].text.lower() == 'the ' + newspaper.lower()]
                found = False
                if len(search) == 1 or len(search) == 2:
                    result = [x for x in b.find_elements_by_css_selector('.record-result') if  x.find_elements_by_tag_name('a')[1].text.lower() == 'the ' + newspaper.lower()][0]
                    found = True
                else:
                    print('unclear results', newspaper)
                    skip = True
            if found:
                link = result.find_element_by_tag_name('a').get_attribute('href')
                location = result.find_element_by_css_selector('.titledesc').text

                Path(datafile).write_text(json.dumps({'newspaper': newspaper, 'link': link, 'location': location}))
        elif len(b.find_elements_by_css_selector('.record-result')) == 1:
            result = b.find_element_by_css_selector('.record-result')
            link = result.find_element_by_tag_name('a').get_attribute('href')
            location = result.find_element_by_css_selector('.titledesc').text
            
            Path(datafile).write_text(json.dumps({'newspaper': newspaper, 'link': link, 'location': location}))
        else:
            print('no result')
# Out:
# Brooklyn Life and Activities of Long Island Society
# Bradford Evening Star and The Bradford Daily Record
# The Ventura County Star and the Ventura Daily Post
# Camden Morning Post
# Rochester Democrat and Chronicle
# Pottsville Republican and Herald
# Chillicothe Constitution-Tribune
# Statesville Record And Landmark
# Hutchinson News
# Colorado Springs Gazette Telegraph
# Petaluma Daily Morning Courier
# Binghamton Press and Sun-Bulletin
# Orangeburg Times and Democrat
# Massillon Evening Independent
# Los Angeles Evening Citizen News
# Harlingen Valley Morning Star
# Haleyville Advertiser-Journal
# East Liverpool Evening Review
# Decatur Wise County Messenger
# Alton Illinois Evening Telegraph
# Yuba City Independent-Herald
# Springfield Leader and Press
# New Philadelphia Daily Times
# Monongahela Daily Republican
# Los Angeles Evening Post-Record
# Klamath Falls Evening Herald
# Benton Harbor News-Palladium
# Corpus Christi Caller-Times
# Canandaigua Daily Messenger
# ...
