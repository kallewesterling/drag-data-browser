# %%
from pathlib import Path
import re
from tqdm import tqdm
from slugify import slugify
import os, json, datetime

# %%
POTENTIAL_PATHS = [
    # zero means always reload
    ("/Users/kallewesterling/Desktop/", 1),
 
    # 7 means once per week
    ("/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My own clippings and photos/", 7),

    # 14 means once every two weeks
    ("/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- newspapers.com", 14),
    
    # 60 means once every two months
    ("/Volumes/External", 60),
]

POTENTIAL_FILE_ENDINGS = [".png"]

# %%
NEWSPAPER_ID = re.compile(r"(\d{8,9})")
newspaper_id_files = {}
found_in_dirs = []

# %%
class DirectoryCache():
    directory = None
    expiry_days = None
    filepath = None
    file_endings = None
    content = {}
    
    def __init__(self, directory, expiry_days, file_endings):
        self.directory = directory
        self.expiry_days = expiry_days
        self.file_endings = file_endings
        self.filepath = self.setup_filepath()
        if not Path(self.filepath).exists():
            print(f'no cache file exists yet...')
        else:
            if self.check_expiry() == True:
                print(f'cache expired... removing {self.filepath} and reloading data')
                self.drop()
            else:
                self.content = self.read()
            
    def setup_filepath(self):
        if not Path('.DirectoryCache').exists():
            Path('.DirectoryCache').mkdir(parents=True)
            
        return Path(f'.DirectoryCache/{slugify("-".join(self.file_endings) + "-" + self.directory)}.json')
        
    def check_expiry(self):
        min_created = datetime.datetime.now() - datetime.timedelta(days=self.expiry_days)
        date_created = datetime.datetime.fromtimestamp(Path(self.filepath).stat().st_mtime)
        if date_created > min_created:
            return False
        else:
            return True
        
    def drop(self):
        if self.filepath.exists():
            self.filepath.unlink()
        
    def save(self):
        print('---> saving cache data')
        Path(self.filepath).write_text(json.dumps(self.content))
        
    def read(self):
        return json.loads(Path(self.filepath).read_text())
    
    @property
    def newspaper_ids(self):
        return list(self.content.keys())

# %%
for PATH, EXPIRY_DAYS in POTENTIAL_PATHS:
    cache = DirectoryCache(PATH, EXPIRY_DAYS, POTENTIAL_FILE_ENDINGS)
    if not cache.content:
        found_files = {}
        for subdir, dirs, files in os.walk(PATH):
            for file in files:
                filepath = subdir + os.sep + file

                if "." + file.split(".")[-1] in POTENTIAL_FILE_ENDINGS:
                    newspaper_id = None
                    has_newspaper_id = NEWSPAPER_ID.search(str(file))

                    if has_newspaper_id:
                        newspaper_id = has_newspaper_id.groups()[0]

                    if newspaper_id and not newspaper_id in found_files:
                        found_files[newspaper_id] = []

                    if newspaper_id:
                        found_files[newspaper_id].append(filepath)
                        found_in_dirs.append(subdir)
                        found_in_dirs = list(set(found_in_dirs))
        cache.content = found_files
        cache.save()
    
    cache = DirectoryCache(PATH, EXPIRY_DAYS, POTENTIAL_FILE_ENDINGS)
    # cache.directory, cache.newspaper_ids

# %%
from pprint import pprint

# pprint(newspaper_id_files)
pprint(found_in_dirs)
# Out:
# ['/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Stroud, Frankie [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Warren, Roni [performer]/Roni Warren '
#  '(newspapers.com)',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Beryl, Billie [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Fredericks, Leon [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Jewel Box Revue [group]',
#  '/Users/kallewesterling/Desktop/New Folder With Items 2',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Renault, Francis [performer]/newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Dante's Inferno [venue]",
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Gilbert, Ralph [performer]',
#  '/Users/kallewesterling/Desktop/female imps 1930-1940 newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/La Verde, Leon [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/ambisextrous [subject; general]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Valdez, Verne [performer]/Vern or Verne Valdez '
#  'newspapers.com 1900- 1950',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Vaughn, Alberta [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- '
#  'newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/limp wrists [subject; general]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Galucci, Nicki (aka Male Lily Pons) [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Jimmy's Back Yard [venue]",
#  '/Users/kallewesterling/Desktop/New Folder With Items',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Anderson, Bobby [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Female Impersonators of America [organization]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Knoll's Inn [venue]/newspapers.com - knoll's inn "
#  "(1930-1940) NOT Breezy Knoll's, Knollwood, or Pine Knoll's",
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/La Monte, Gene [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/drag [subject; general]/pre-1900 material',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/drag ball [subject; general]/"drag party" US -1900',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Coffee Cliffs [venue]/newspapers.com 1927-1935 '
#  '(partial)',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Carew & O'Connor [group]",
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Maye, Jackie [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Mack, Lyle [performer]/Lyle Mack newspapers.com '
#  '1930-1940',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Gilmore, Gita [performer]/newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Lee, Les [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Barrios, Jean [performer]/newspapers.com 1920-1930',
#  '/Users/kallewesterling/Desktop/Billie Beryl 1930-1940 newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Lavana, Boots [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Ames, Adrian (aka Lionel Mike Ames) [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Barlow, Freddie [performer]',
#  '/Users/kallewesterling/Desktop/sort',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/St. Julian [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Bourbon, Rae [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/homosexuality, historical views on [subject; '
#  'general]/sissies NY, 1930 (partial)',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Norman, Karyl [performer]/Karyl Normann '
#  'newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Funny Fanny [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Rohmer, Billy [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Mangum, Johnnie [performer]/newspapers.com all',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/La Verne, Francis [performer]',
#  '/Users/kallewesterling/Desktop/Club Renault Revue',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Blease, Johnny [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/K9 Club [venue]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Lee, Harvey [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Finocchio's [venue]/Finnochio's 1930-1940 "
#  'California newspapers',
#  '/Users/kallewesterling/Desktop/',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Le Roy, Del [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Charms, Chickie [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/La Monte, Terry [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Landick, Olyn [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  "own clippings and photos/Tait's [venue; San Francisco]",
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Club Frontenac [venue]/newspapers.com',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Gordon, Jackie [performer]',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Rose, La Belle [performer]',
#  '/Users/kallewesterling/Desktop/Timeline articles (newspapers.com)',
#  '/Volumes/GoogleDrive/My Drive/Ongoing Projects/Dissertation - Archive/- My '
#  'own clippings and photos/Jarahal [performer]/newspapers.com 1930-1940']
