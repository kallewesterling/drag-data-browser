# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))

# %%
import pandas as pd
import re
from datetime import datetime as dt

YEAR_RANGE = (1930, 1940)

def remove(row):
    try:
        date = dt.strptime(row.Date, '%Y-%m-%d')
    except:
        return True
    
    if YEAR_RANGE and date.year >= YEAR_RANGE[0] and date.year <= YEAR_RANGE[1]:
        pass # in the range!
    else:
        return True

    if row['Exclude from visualization'] or row['Unsure whether drag artist']:
        return True
    
    no_city = row['City'] == ''
    no_performer = row['Performer'] == ''
    no_venue = row['Venue'] == ''
    unnamed_performer = 'unnamed' in row['Performer'].lower()
    
    if no_city and no_performer and no_venue:
        return True
    
    if unnamed_performer:
        return True

    return False

def extract_addresses_dict(normalized_df):
    addresses = {}
    rows_with_addresses = normalized_df[normalized_df['Address']!='']
    warnings = []
    for x in zip(rows_with_addresses['Date'], rows_with_addresses['Source'], rows_with_addresses['Venue'], rows_with_addresses['Address']):
        date, source, venue, address = x
        if venue == '':
            warnings.append(address)
        else:
            if not venue in addresses:
                addresses[venue] = {}
            if not source in addresses[venue]:
                addresses[venue][source] = address
    if len(warnings):
        print(f'Warning: {len(warnings)} Venues with no names have addresses:')
        print('- ' + '- '.join(warnings))

    return addresses

def reverse_comment_dict(comment_dict):
    comments_reverse = {}
    for performer, comments in comment_dict.items():
        if not performer in comments_reverse:
            comments_reverse[performer] = {}
        for source, comment in comments.items():
            if not comment in comments_reverse[performer]:
                comments_reverse[performer][comment] = []
            comments_reverse[performer][comment].append(source)
    return comments_reverse
        
def get_comments(df, comment_field='Comment on edge: revue', match_field='Revue', transform=None):
    comments = {}
    rows_with_comments = df[df[comment_field]!='']
    warnings = []
    for x in zip(rows_with_comments['Date'], rows_with_comments['Source'], rows_with_comments[match_field], rows_with_comments[comment_field]):
        date, source, match, comment = x
        comment = str(comment).strip()
        if transform:
            comment = transform(comment)
        if match == '':
            warnings.append(str(comment)[:40]+'...')
        else:
            if not match in comments:
                comments[match] = {}
            if not source in comments[match]:
                comments[match][source] = comment
    if len(warnings):
        print(f'Warning: {len(warnings)} mentions in `{comment_field}` with no value have comments:')
        print('- ' + '\n- '.join(warnings))

    return comments

def get_revue_comments_dict(df):
    return get_comments(df, 'Comment on edge: revue', 'Revue')

def get_performer_comments_dict(df):
    return get_comments(df, 'Comment on node: performer', 'Performer')

def get_venue_comments_dict(df):
    return get_comments(df, 'Comment on node: venue', 'Venue')

def get_city_comments_dict(df):
    return get_comments(df, 'Comment on node: city', 'City')

def get_true_value(row, type):
    if type == 'source':
        if row['Source clean'] != '':
            return row['Source clean']
        return row['Source']
    if type == 'performer':
        if row['Normalized performer'] != '':
            return row['Normalized performer']
        if row['Performer first-name'] != '' and row['Performer last-name'] != '':
            return row['Normalized performer']
        return row['Performer']
    if type == 'city':
        if row['Normalized City'] != '':
            return row['Normalized City']
        return row['City']
    if type == 'revue':
        if row['Normalized Revue Name'] != '':
            return row['Normalized Revue Name']
        return row['Revue name']
    if type == 'venue':
        if row['Normalized Venue'] != '':
            return row['Normalized Venue']
        return row['Venue']
    raise NotImplementedError(f'type `{type}` is not yet implemented')

def find_ref(row, eima=True):
    source = row.get('Source', '')
    source += ' ' + str(row.get('EIMA_ID', ''))
    source += ' ' + str(row.get('Newspapers_ID', ''))
    source += ' ' + str(row.get('EIMA', ''))
    source += ' ' + str(row.get('Search (newspapers.com)', ''))
    source += ' ' + str(row.get('Source clean', ''))
    
    is_eima = 'eima' in source.lower() or 'variety' in source.lower() or 'billboard' in source.lower()
    has_ref = re.search(r'(\d{7,10})', source)
    refs = list(set(re.findall(r'(\d{7,10})', source)))
    if has_ref and eima and is_eima:
        return '|'.join(refs)
    
    if has_ref and not eima and not is_eima:
        return '|'.join(refs)

    return ''
    

df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=254069133&single=true&output=csv')
df = df.fillna('')
df = df.replace('—', '')
df = df.replace('—*', '')



# First, set up our references to EIMA and newspapers.com
df['EIMA'] = df.apply(lambda row: find_ref(row), axis=1)
df['Newspapers.com'] = df.apply(lambda row: find_ref(row, False), axis=1)

# Normalize dataframe
df['Source'] = df.apply(lambda row: get_true_value(row, 'source'), axis=1)
df['Venue'] = df.apply(lambda row: get_true_value(row, 'venue'), axis=1)
df['Performer'] = df.apply(lambda row: get_true_value(row, 'performer'), axis=1)
df['City'] = df.apply(lambda row: get_true_value(row, 'city'), axis=1)
df['Revue'] = df.apply(lambda row: get_true_value(row, 'revue'), axis=1)


# Drop filtered data
df['remove'] = df.apply(lambda row: remove(row), axis=1)
df = df.drop(df[df['remove']==True].index)

# %%
months = ['', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
DATE = re.compile(r'('+'|'.join([x for x in months if x])+') (\d{1,2}), (\d{4})')
STATE = re.compile(r' ([A-Z][A-Z])( |\])')

# %%
from collections import Counter

incorrect_refs = []
papers_no_state = Counter()

for paper, references in {_: [y for y in x.Source] for _, x in df.groupby('Newspaper')}.items():
    state = None
    if not paper or paper.startswith('*'):
        continue
    for reference in references:
        if 'page unknown' in reference or 'date unclear' in reference:
            continue
        reference = reference.replace(paper, '').strip(',')
        if DATE.search(reference):
            month_text, day, year = DATE.search(reference).groups()
            month = str(months.index(month_text)).zfill(2)
            if STATE.search(paper):
                #print(reference, STATE.search(reference))
                state = abbrev_us_state[STATE.search(paper).groups()[0]]
                # print(state)
            else:
                for state_ in abbrev_us_state.values():
                    if state_ in paper:
                        state = state_
        else:
            incorrect_refs.append((paper, reference))
            continue
        
        if not state and 'Canada' not in paper:
            papers_no_state[paper] += 1
            
incorrect_refs = list(set(incorrect_refs))
if incorrect_refs:
    print(f'ERROR: INCORRECT REFERENCES:')
    for ref in incorrect_refs:
        print(incorrect_refs)
# Out:
# ERROR: INCORRECT REFERENCES:
# [('Broadway Tattler [New York NY]', 'Broadway Tattler, March 1933, 12 and 14')]

# %%
papers_no_state.most_common()
# Out:
# []

# %%
def getmax(list1, N=10):
    final_list = []
  
    for i in range(0, N): 
        max1 = 0
          
        for j in range(len(list1)):     
            if list1[j] > max1:
                max1 = list1[j];
                  
        list1.remove(max1);
        final_list.append(max1)
          
    return(final_list)
    
from slugify import slugify

tagged_by_state = {x[1]: {y: 0 for y in range(1930,1941)} for x, _ in df.groupby(['year', 'state']) if x[1]}
performer_by_year = {x[1]: {y: [] for y in range(1930,1941)} for x, _ in df.groupby(['year', 'state']) if x[1]}

for groups, rows in df.groupby(['year', 'state']):
    year, state = groups
    if not state:
        continue
    
    tagged_by_state.setdefault(state, {})[year] = len(rows)
    performer_by_year.setdefault(state, {})[year] = list(set(x for x in rows.Performer if x))

    # print(year, state, len(rows))
    '''
        node_data = {
            'display': f'{state}, {year}',
            'name': slugify(f'{state}, {year}')
        }
        
        nodes.append(node_data)
    '''
    
tagged_by_state
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-af93b4d4fe68> in <module>
#      16 from slugify import slugify
#      17
# ---> 18 tagged_by_state = {x[1]: {y: 0 for y in range(1930,1941)} for x, _ in df.groupby(['year', 'state']) if x[1]}
#      19 performer_by_year = {x[1]: {y: [] for y in range(1930,1941)} for x, _ in df.groupby(['year', 'state']) if x[1]}
#      20
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'year'

# %%
all_values = {}
for state in tagged_by_state:
    for year in tagged_by_state[state]:
        nums = tagged_by_state[state][year]
        all_values.setdefault(year, []).extend([nums])

for year in all_values:
    all_values[year] = getmax(all_values[year])
    
# new all_values contains all the top values for our data

# %%
for year in all_values:
    max_values = all_values[year]
    for state in tagged_by_state:
        if tagged_by_state[state][year] in max_values:
            print(state, year, tagged_by_state[state][year])

# %%
def sumup(performer_data):
    _ = 0
    for key in performer_data:
        _ += len([x for x in performer_data[key]])
    return _

states = [x for x in performer_by_year]
years = range(1930, 1941)
# [performer_by_year[x][1930] for x in states]

all_state_performers = {}
for state in states:
    state_performers = []
    for year in years:
        [state_performers.extend(performer_by_year[x][year]) for x in states]
    state_performers = sorted(list(set(state_performers)))
    
    for performer in state_performers:
        years_appeared = []
        for year in years:
            if performer in performer_by_year[state][year]:
                # print('found', performer, 'in', state, year)
                years_appeared.append(year)
        all_state_performers.setdefault(performer, {})[state] = years_appeared

for performer in all_state_performers:
    print(performer, sumup(all_state_performers[performer]))
    
all_state_performers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-92f2d6c14901> in <module>
#       5     return _
#       6
# ----> 7 states = [x for x in performer_by_year]
#       8 years = range(1930, 1941)
#       9 # [performer_by_year[x][1930] for x in states]
#
# NameError: name 'performer_by_year' is not defined

# %%
nodes = []
links = []
for state in tagged_by_state:
    for year in tagged_by_state[state]:
        name = f'{state} {year}'
        display = slugify(f'{state} {year}')
        count = tagged_by_state[state][year]
        node = {
            'name': name,
            'display': display,
            'count': count
        }
        nodes.append(node)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-b1c9a3530ed3> in <module>
#       1 nodes = []
#       2 links = []
# ----> 3 for state in tagged_by_state:
#       4     for year in tagged_by_state[state]:
#       5         name = f'{state} {year}'
#
# NameError: name 'tagged_by_state' is not defined

# %%
nodes
# Out:
# []

# %%
#### Rethink quickly as object

# %%
'''
import pandas as pd
import re
from datetime import datetime as dt

YEAR_RANGE = (1930, 1940)

def remove(row):
    try:
        date = dt.strptime(row.Date, '%Y-%m-%d')
    except:
        return True
    
    if YEAR_RANGE and date.year >= YEAR_RANGE[0] and date.year <= YEAR_RANGE[1]:
        pass # in the range!
    else:
        return True

    if row['Exclude from visualization'] or row['Unsure whether drag artist']:
        return True
    
    no_city = row['City'] == ''
    no_performer = row['Performer'] == ''
    no_venue = row['Venue'] == ''
    unnamed_performer = 'unnamed' in row['Performer'].lower()
    
    if no_city and no_performer and no_venue:
        return True
    
    if unnamed_performer:
        return True

    return False

def extract_addresses_dict(normalized_df):
    addresses = {}
    rows_with_addresses = normalized_df[normalized_df['Address']!='']
    warnings = []
    for x in zip(rows_with_addresses['Date'], rows_with_addresses['Source'], rows_with_addresses['Venue'], rows_with_addresses['Address']):
        date, source, venue, address = x
        if venue == '':
            warnings.append(address)
        else:
            if not venue in addresses:
                addresses[venue] = {}
            if not source in addresses[venue]:
                addresses[venue][source] = address
    if len(warnings):
        print(f'Warning: {len(warnings)} Venues with no names have addresses:')
        print('- ' + '- '.join(warnings))

    return addresses

def reverse_comment_dict(comment_dict):
    comments_reverse = {}
    for performer, comments in comment_dict.items():
        if not performer in comments_reverse:
            comments_reverse[performer] = {}
        for source, comment in comments.items():
            if not comment in comments_reverse[performer]:
                comments_reverse[performer][comment] = []
            comments_reverse[performer][comment].append(source)
    return comments_reverse
        
def get_comments(df, comment_field='Comment on edge: revue', match_field='Revue', transform=None):
    comments = {}
    rows_with_comments = df[df[comment_field]!='']
    warnings = []
    for x in zip(rows_with_comments['Date'], rows_with_comments['Source'], rows_with_comments[match_field], rows_with_comments[comment_field]):
        date, source, match, comment = x
        comment = str(comment).strip()
        if transform:
            comment = transform(comment)
        if match == '':
            warnings.append(str(comment)[:40]+'...')
        else:
            if not match in comments:
                comments[match] = {}
            if not source in comments[match]:
                comments[match][source] = comment
    if len(warnings):
        print(f'Warning: {len(warnings)} mentions in `{comment_field}` with no value have comments:')
        print('- ' + '\n- '.join(warnings))

    return comments

def get_revue_comments_dict(df):
    return get_comments(df, 'Comment on edge: revue', 'Revue')

def get_performer_comments_dict(df):
    return get_comments(df, 'Comment on node: performer', 'Performer')

def get_venue_comments_dict(df):
    return get_comments(df, 'Comment on node: venue', 'Venue')

def get_city_comments_dict(df):
    return get_comments(df, 'Comment on node: city', 'City')

def get_true_value(row, type):
    if type == 'source':
        if row['Source clean'] != '':
            return row['Source clean']
        return row['Source']
    if type == 'performer':
        if row['Normalized performer'] != '':
            return row['Normalized performer']
        if row['Performer first-name'] != '' and row['Performer last-name'] != '':
            return row['Normalized performer']
        return row['Performer']
    if type == 'city':
        if row['Normalized City'] != '':
            return row['Normalized City']
        return row['City']
    if type == 'revue':
        if row['Normalized Revue Name'] != '':
            return row['Normalized Revue Name']
        return row['Revue name']
    if type == 'venue':
        if row['Normalized Venue'] != '':
            return row['Normalized Venue']
        return row['Venue']
    raise NotImplementedError(f'type `{type}` is not yet implemented')

def find_ref(row, eima=True):
    source = row.get('Source', '')
    source += ' ' + str(row.get('EIMA_ID', ''))
    source += ' ' + str(row.get('Newspapers_ID', ''))
    source += ' ' + str(row.get('EIMA', ''))
    source += ' ' + str(row.get('Search (newspapers.com)', ''))
    source += ' ' + str(row.get('Source clean', ''))
    
    is_eima = 'eima' in source.lower() or 'variety' in source.lower() or 'billboard' in source.lower()
    has_ref = re.search(r'(\d{7,10})', source)
    refs = list(set(re.findall(r'(\d{7,10})', source)))
    if has_ref and eima and is_eima:
        return '|'.join(refs)
    
    if has_ref and not eima and not is_eima:
        return '|'.join(refs)

    return ''
    

df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=254069133&single=true&output=csv')
df = df.fillna('')
df = df.replace('—', '')
df = df.replace('—*', '')



# First, set up our references to EIMA and newspapers.com
df['EIMA'] = df.apply(lambda row: find_ref(row), axis=1)
df['Newspapers.com'] = df.apply(lambda row: find_ref(row, False), axis=1)

# Normalize dataframe
df['Source'] = df.apply(lambda row: get_true_value(row, 'source'), axis=1)
df['Venue'] = df.apply(lambda row: get_true_value(row, 'venue'), axis=1)
df['Performer'] = df.apply(lambda row: get_true_value(row, 'performer'), axis=1)
df['City'] = df.apply(lambda row: get_true_value(row, 'city'), axis=1)
df['Revue'] = df.apply(lambda row: get_true_value(row, 'revue'), axis=1)


# Drop filtered data
df['remove'] = df.apply(lambda row: remove(row), axis=1)
df = df.drop(df[df['remove']==True].index)
'''
pass

# %%
'''
class Source():
    newspaper = None
    reference = None
    edges = []
    eima_id = None
    newspaper_id = None
    
    def __init__(self):
        pass
    
    def __str__(self):
        return f'{eima_id}, {newspaper_id}'
        
for source, rows in df.groupby('Source'):
    s = Source()
    edges = list(zip([x for x in rows.Performer], list(zip([x for x in rows.Venue], [x for x in rows.City]))))
    tagged_performers = list(set([x for x in rows.Performer]))
    tagged_venues = list(set(zip([x for x in rows.Venue], [x for x in rows.City])))
    dates = list(set(x for x in rows.Date))
    eima_id = list(set(x for x in rows.EIMA_ID if x))
    if eima_id:
        s.eima_id = eima_id[0]
    newspaper_id = list(set([x for x in rows.Newspaper_ID if x]))
    if newspaper_id:
        s.newspaper_id = newspaper_id[0]
    if len(dates) > 1:
        print(len(tagged_performers))
        print(len(tagged_venues))
        print(source)
    
    print(s)
'''
pass

# %%
def get_state(row):
    city, *state = row.City.split(', ')
    if not state:
        return ''
    state = state[0]
    if state in ['Canada', 'Mexico', 'Cuba', 'Switzerland']:
        return ''
    
    state = abbrev_us_state[state]
    return state
    

df['year'] = df.apply(lambda row: pd.to_datetime(row['Date']).year, axis=1)
df['state'] = df.apply(lambda row: get_state(row), axis=1)


for x, _ in df.groupby(['year', 'state', 'Performer']):
    year, state, performer = x

# %%
all_travels = {x: {y: [] for y in range(1930,1941)} for x in sorted(list(set(x for x in df.Performer if x)))}

for _, rows in df.groupby(['year', 'state', 'Performer']):
    year, state, performer = _
    if not state or not performer:
        continue
    
    next_year = None
    if year < 1940:
        next_year = year+1
    
    _from = state
    to = []
    if next_year:
        performer_safe = performer.replace('"', '\\"')
        to = list(set(x for x in df.query(f'Performer=="{performer_safe}" & year=="{next_year}" ').state if x))
    
    if to:
        all_travels[performer][year] = (_from, to)
    #print(df[(df.Performer == performer & df.year == )])

# %%
# We're going to create the sankey diagram, where we will assume that the performer stayed in the same place as they last arrived

def last_previous_trip(performer, year):
    all_years = range(1930,1941)
    
    # find the last recorded trip for the performer
    year = year - 1
    while year >= min(all_years):
        if len(all_travels[performer][year]):
            return (year, all_travels[performer][year][1][-1])
            year = 9999
        else:
            year = year - 1
    return (None, None)

padded_travels = {x: {y: {'from': None, 'to': [None]} for y in range(1930,1941)} for x in sorted(list(set(x for x in df.Performer if x)))}

for performer, travels in all_travels.items():
    years_recorded = 0
    for year in travels:
        if len(travels[year]) > 1:
            years_recorded += 1
    if not years_recorded:
        print()
        print('***********')
        print(performer, '(no trips)')
        del padded_travels[performer]
        print('***********')
        continue
    else:
        print()
        print('***********')
        print(performer)
        print('***********')
        if years_recorded == 8:
            pass # print(performer, travels) # For this performer, we have everything recorded
    for year, trip in travels.items():
        if trip:
            _from, to = trip
            if len(to) == 1 and to[0] == _from:
                print(f'in {year}, {performer} was only found in {_from}')
            elif len(to) == 1:
                print(f'in {year}, {performer} traveled from {_from} to {to[0]}')
            elif len(to) > 0:
                print(f'in {year}, {performer} traveled from {_from} to')
                print('- ' + '\n'.join(to))
            padded_travels[performer][year] = {
                'from': _from,
                'to': to,
                'inferred': False
            }
        else:
            previous_trip_year, previous_trip_from = last_previous_trip(performer, year)
            if previous_trip_year:
                # print(f'{performer} did not travel in {year} but we looked backwards and saw that they were last in {previous_trip_from} in {previous_trip_year} (need to fill out {list(range(previous_trip_year+1, year+1))}).')
                print(f'{performer} did not travel in {year} but we will assume that they stayed in their last location ({previous_trip_from}) since {previous_trip_year}. --> means we have to fill out {list(range(previous_trip_year+1, year+1))}')
            else:
                print(f'{performer} did not travel in {year} but we looked backwards and saw that we do not have a previously recorded trip')
            padded_travels[performer][year] = {
                'from': previous_trip_from,
                'to': [previous_trip_from],
                'inferred': True
            }
# Out:
# ***********
# Adrian Ames
# ***********
# in 1930, Adrian Ames was only found in New York
# Adrian Ames did not travel in 1931 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931]
# Adrian Ames did not travel in 1932 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932]
# Adrian Ames did not travel in 1933 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933]
# in 1934, Adrian Ames was only found in New York
# Adrian Ames did not travel in 1935 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935]
# Adrian Ames did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935, 1936]
# Adrian Ames did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935, 1936, 1937]
# Adrian Ames did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938]
# Adrian Ames did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939]
# Adrian Ames did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Adrian Norris (no trips)
# ***********
#
# ***********
# Adrienne (no trips)
# ***********
#
# ***********
# Al Benson
# ***********
# Al Benson did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Al Benson did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Al Benson did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Al Benson was only found in Illinois
# Al Benson did not travel in 1934 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934]
# Al Benson did not travel in 1935 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935]
# Al Benson did not travel in 1936 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935, 1936]
# Al Benson did not travel in 1937 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937]
# Al Benson did not travel in 1938 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938]
# Al Benson did not travel in 1939 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939]
# Al Benson did not travel in 1940 but we will assume that they stayed in their last location (Illinois) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Al DeMarco
# ***********
# Al DeMarco did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Al DeMarco did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Al DeMarco did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Al DeMarco did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Al DeMarco was only found in New York
# in 1935, Al DeMarco was only found in New York
# in 1936, Al DeMarco traveled from New York to Pennsylvania
# Al DeMarco did not travel in 1937 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937]
# Al DeMarco did not travel in 1938 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937, 1938]
# Al DeMarco did not travel in 1939 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937, 1938, 1939]
# Al DeMarco did not travel in 1940 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937, 1938, 1939, 1940]
#
# ***********
# Al Garbell (no trips)
# ***********
#
# ***********
# Al Lucas (no trips)
# ***********
#
# ***********
# Al Ray (no trips)
# ***********
#
# ***********
# Alberta Vaughn
# ***********
# Alberta Vaughn did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Alberta Vaughn did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Alberta Vaughn did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Alberta Vaughn did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Alberta Vaughn did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Alberta Vaughn traveled from Pennsylvania to
# - Michigan
# Kentucky
# in 1936, Alberta Vaughn was only found in Michigan
# in 1937, Alberta Vaughn traveled from Michigan to Minnesota
# in 1938, Alberta Vaughn traveled from Minnesota to Wisconsin
# Alberta Vaughn did not travel in 1939 but we will assume that they stayed in their last location (Wisconsin) since 1938. --> means we have to fill out [1939]
# Alberta Vaughn did not travel in 1940 but we will assume that they stayed in their last location (Wisconsin) since 1938. --> means we have to fill out [1939, 1940]
#
# ***********
# Alden Garrison (no trips)
# ***********
#
# ***********
# Alfred Carmen (no trips)
# ***********
#
# ***********
# Alice Rydner (no trips)
# ***********
#
# ***********
# Alice White
# ***********
# Alice White did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# Alice White did not travel in 1938 but we looked backwards and saw that we do not have a previously recorded trip
# in 1939, Alice White was only found in Illinois
# Alice White did not travel in 1940 but we will assume that they stayed in their last location (Illinois) since 1939. --> means we have to fill out [1940]
#
# ***********
# Allen Carl (no trips)
# ***********
#
# ***********
# Andrew Tribble (no trips)
# ***********
#
# ***********
# Andy Cliff (no trips)
# ***********
#
# ***********
# Anthony DiMeo (no trips)
# ***********
#
# ***********
# Arica Wild
# ***********
# Arica Wild did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Arica Wild did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Arica Wild did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Arica Wild traveled from New Jersey to
# - New Jersey
# New York
# in 1934, Arica Wild was only found in New York
# in 1935, Arica Wild traveled from New York to New Jersey
# Arica Wild did not travel in 1936 but we will assume that they stayed in their last location (New Jersey) since 1935. --> means we have to fill out [1936]
# Arica Wild did not travel in 1937 but we will assume that they stayed in their last location (New Jersey) since 1935. --> means we have to fill out [1936, 1937]
# Arica Wild did not travel in 1938 but we will assume that they stayed in their last location (New Jersey) since 1935. --> means we have to fill out [1936, 1937, 1938]
# Arica Wild did not travel in 1939 but we will assume that they stayed in their last location (New Jersey) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939]
# Arica Wild did not travel in 1940 but we will assume that they stayed in their last location (New Jersey) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939, 1940]
#
# ***********
# Art Bernard (no trips)
# ***********
#
# ***********
# Art West
# ***********
# Art West did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Art West did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Art West did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Art West did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Art West did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Art West traveled from Missouri to Ohio
# Art West did not travel in 1936 but we will assume that they stayed in their last location (Ohio) since 1935. --> means we have to fill out [1936]
# Art West did not travel in 1937 but we will assume that they stayed in their last location (Ohio) since 1935. --> means we have to fill out [1936, 1937]
# Art West did not travel in 1938 but we will assume that they stayed in their last location (Ohio) since 1935. --> means we have to fill out [1936, 1937, 1938]
# Art West did not travel in 1939 but we will assume that they stayed in their last location (Ohio) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939]
# Art West did not travel in 1940 but we will assume that they stayed in their last location (Ohio) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939, 1940]
#
# ***********
# Arthur Budd
# ***********
# in 1930, Arthur Budd was only found in New York
# in 1931, Arthur Budd was only found in New York
# in 1932, Arthur Budd was only found in New York
# Arthur Budd did not travel in 1933 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933]
# Arthur Budd did not travel in 1934 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934]
# Arthur Budd did not travel in 1935 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935]
# Arthur Budd did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935, 1936]
# Arthur Budd did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935, 1936, 1937]
# Arthur Budd did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935, 1936, 1937, 1938]
# Arthur Budd did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935, 1936, 1937, 1938, 1939]
# Arthur Budd did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1932. --> means we have to fill out [1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Arthur G. West
# ***********
# in 1930, Arthur G. West traveled from Wisconsin to
# - New Jersey
# New York
# Arthur G. West did not travel in 1931 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931]
# Arthur G. West did not travel in 1932 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932]
# Arthur G. West did not travel in 1933 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933]
# Arthur G. West did not travel in 1934 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934]
# Arthur G. West did not travel in 1935 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935]
# Arthur G. West did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936]
# Arthur G. West did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937]
# Arthur G. West did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938]
# Arthur G. West did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939]
# Arthur G. West did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Arthur La Delle (no trips)
# ***********
#
# ***********
# Arvin Giese (no trips)
# ***********
#
# ***********
# Bab Garrison (no trips)
# ***********
#
# ***********
# Babe Allen
# ***********
# Babe Allen did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Babe Allen did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Babe Allen did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Babe Allen did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Babe Allen traveled from Florida to
# - Missouri
# Florida
# Illinois
# Maryland
# Babe Allen did not travel in 1935 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935]
# Babe Allen did not travel in 1936 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936]
# Babe Allen did not travel in 1937 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937]
# Babe Allen did not travel in 1938 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938]
# Babe Allen did not travel in 1939 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939]
# Babe Allen did not travel in 1940 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Babe Baker (no trips)
# ***********
#
# ***********
# Barbette
# ***********
# Barbette did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Barbette did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Barbette did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Barbette did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Barbette did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Barbette was only found in New York
# Barbette did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1935. --> means we have to fill out [1936]
# Barbette did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1935. --> means we have to fill out [1936, 1937]
# Barbette did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1935. --> means we have to fill out [1936, 1937, 1938]
# Barbette did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939]
# Barbette did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1935. --> means we have to fill out [1936, 1937, 1938, 1939, 1940]
#
# ***********
# Bel Ager (no trips)
# ***********
#
# ***********
# Benny Pauly (no trips)
# ***********
#
# ***********
# Bernie Salin (no trips)
# ***********
#
# ***********
# Bert Errol (no trips)
# ***********
#
# ***********
# Bert Sherry
# ***********
# Bert Sherry did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Bert Sherry did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Bert Sherry did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Bert Sherry did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Bert Sherry was only found in Maryland
# Bert Sherry did not travel in 1935 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935]
# Bert Sherry did not travel in 1936 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936]
# Bert Sherry did not travel in 1937 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937]
# Bert Sherry did not travel in 1938 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938]
# Bert Sherry did not travel in 1939 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939]
# Bert Sherry did not travel in 1940 but we will assume that they stayed in their last location (Maryland) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Bert Wheeler (no trips)
# ***********
#
# ***********
# Bertie Bierman (no trips)
# ***********
#
# ***********
# Bill Jones (no trips)
# ***********
#
# ***********
# Bill Kennedy
# ***********
# Bill Kennedy did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# Bill Kennedy did not travel in 1938 but we looked backwards and saw that we do not have a previously recorded trip
# Billie Davis did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939]
# Billie Davis did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Billie Dove (no trips)
# ***********
#
# ***********
# Billie Marsh (no trips)
# ***********
#
# ***********
# Billie McAllister (no trips)
# ***********
#
# ***********
# Billie Russell
# ***********
# Billie Russell did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billie Russell did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billie Russell did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Billie Russell was only found in Illinois
# in 1934, Billie Russell traveled from Illinois to
# - Missouri
# Florida
# Illinois
# Billie Russell did not travel in 1935 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935]
# Billie Russell did not travel in 1936 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935, 1936]
# Billie Russell did not travel in 1937 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935, 1936, 1937]
# Billie Russell did not travel in 1938 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938]
# Billie Russell did not travel in 1939 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939]
# Billie Russell did not travel in 1940 but we will assume that they stayed in their last location (Illinois) since 1934. --> means we have to fill out [1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Billy (no trips)
# ***********
#
# ***********
# Billy "Senorita" Herrera
# ***********
# Billy "Senorita" Herrera did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy "Senorita" Herrera did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy "Senorita" Herrera did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Billy "Senorita" Herrera traveled from Wisconsin to Florida
# in 1934, Billy "Senorita" Herrera traveled from Florida to
# - Florida
# Maryland
# in 1935, Billy "Senorita" Herrera traveled from Maryland to
# - Illinois
# Texas
# Maryland
# in 1936, Billy "Senorita" Herrera traveled from Texas to
# - Washington
# Pennsylvania
# in 1937, Billy "Senorita" Herrera traveled from Washington to California
# in 1938, Billy "Senorita" Herrera was only found in California
# in 1939, Billy "Senorita" Herrera traveled from California to
# - California
# Florida
# Billy "Senorita" Herrera did not travel in 1940 but we will assume that they stayed in their last location (Florida) since 1939. --> means we have to fill out [1940]
#
# ***********
# Billy Ardelle (no trips)
# ***********
#
# ***********
# Billy Brill
# ***********
# Billy Brill did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Brill did not travel in 1938 but we looked backwards and saw that we do not have a previously recorded trip
# in 1939, Billy Brill traveled from Pennsylvania to Michigan
# Billy Brill did not travel in 1940 but we will assume that they stayed in their last location (Michigan) since 1939. --> means we have to fill out [1940]
#
# ***********
# Billy Byrne (no trips)
# ***********
#
# ***********
# Billy Hayes
# ***********
# Billy Hayes did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Hayes did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Hayes did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Hayes did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Hayes did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Billy Hayes traveled from New York to Kentucky
# in 1936, Billy Hayes traveled from Kentucky to
# - Michigan
# Kentucky
# in 1937, Billy Hayes traveled from Michigan to Ohio
# in 1938, Billy Hayes traveled from Ohio to Minnesota
# in 1939, Billy Hayes traveled from Minnesota to Michigan
# Billy Hayes did not travel in 1940 but we will assume that they stayed in their last location (Michigan) since 1939. --> means we have to fill out [1940]
#
# ***********
# Billy Irwin
# ***********
# Billy Irwin did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Irwin did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# in 1937, Billy Irwin was only found in Ohio
# Billy Irwin did not travel in 1938 but we will assume that they stayed in their last location (Ohio) since 1937. --> means we have to fill out [1938]
# Billy Irwin did not travel in 1939 but we will assume that they stayed in their last location (Ohio) since 1937. --> means we have to fill out [1938, 1939]
# Billy Irwin did not travel in 1940 but we will assume that they stayed in their last location (Ohio) since 1937. --> means we have to fill out [1938, 1939, 1940]
#
# ***********
# Billy Joy (no trips)
# ***********
#
# ***********
# Billy Kent (no trips)
# ***********
#
# ***********
# Billy O'Brien (no trips)
# ***********
#
# ***********
# Billy Pinnell (no trips)
# ***********
#
# ***********
# Billy Reed
# ***********
# in 1930, Billy Reed was only found in New York
# Billy Reed did not travel in 1931 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931]
# Billy Reed did not travel in 1932 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932]
# Billy Reed did not travel in 1933 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933]
# Billy Reed did not travel in 1934 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934]
# Billy Reed did not travel in 1935 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935]
# Billy Reed did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936]
# Billy Reed did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937]
# Billy Reed did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938]
# Billy Reed did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939]
# Billy Reed did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1930. --> means we have to fill out [1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Billy Richards
# ***********
# Billy Richards did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Richards did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Richards did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Billy Richards traveled from Illinois to
# - Ohio
# Illinois
# in 1934, Billy Richards traveled from Ohio to
# - Missouri
# California
# in 1935, Billy Richards traveled from Missouri to
# - Ohio
# Texas
# in 1936, Billy Richards traveled from Texas to Nevada
# Billy Richards did not travel in 1937 but we will assume that they stayed in their last location (Nevada) since 1936. --> means we have to fill out [1937]
# Billy Richards did not travel in 1938 but we will assume that they stayed in their last location (Nevada) since 1936. --> means we have to fill out [1937, 1938]
# Billy Richards did not travel in 1939 but we will assume that they stayed in their last location (Nevada) since 1936. --> means we have to fill out [1937, 1938, 1939]
# Billy Richards did not travel in 1940 but we will assume that they stayed in their last location (Nevada) since 1936. --> means we have to fill out [1937, 1938, 1939, 1940]
#
# ***********
# Billy Rohmer
# ***********
# Billy Rohmer did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Rohmer did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Rohmer did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Billy Rohmer did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Billy Rohmer traveled from Florida to
# - Florida
# Illinois
# Texas
# Louisiana
# in 1935, Billy Rohmer traveled from Texas to Ohio
# in 1936, Billy Rohmer traveled from Ohio to
# - Michigan
# Washington
# Missouri
# Louisiana
# Billy Rohmer did not travel in 1937 but we will assume that they stayed in their last location (Louisiana) since 1936. --> means we have to fill out [1937]
# Billy Rohmer did not travel in 1938 but we will assume that they stayed in their last location (Louisiana) since 1936. --> means we have to fill out [1937, 1938]
# in 1939, Billy Rohmer was only found in Florida
# Billy Rohmer did not travel in 1940 but we will assume that they stayed in their last location (Florida) since 1939. --> means we have to fill out [1940]
#
# ***********
# Billy Turner (no trips)
# ***********
#
# ***********
# Billy West
# Bobby Allen did not travel in 1940 but we will assume that they stayed in their last location (Ohio) since 1938. --> means we have to fill out [1939, 1940]
#
# ***********
# Bobby Anderson (no trips)
# ***********
#
# ***********
# Bobby Bell (no trips)
# ***********
#
# ***********
# Bobby Brennan (no trips)
# ***********
#
# ***********
# Bobby Cummins (no trips)
# ***********
#
# ***********
# Bobby Dean (no trips)
# ***********
#
# ***********
# Bobby Dell
# ***********
# Bobby Dell did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Dell did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Dell did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Dell did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Bobby Dell was only found in New York
# in 1935, Bobby Dell traveled from New York to
# - Pennsylvania
# New York
# in 1936, Bobby Dell was only found in Pennsylvania
# Bobby Dell did not travel in 1937 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937]
# Bobby Dell did not travel in 1938 but we will assume that they stayed in their last location (Pennsylvania) since 1936. --> means we have to fill out [1937, 1938]
# in 1939, Bobby Dell traveled from New York to Michigan
# Bobby Dell did not travel in 1940 but we will assume that they stayed in their last location (Michigan) since 1939. --> means we have to fill out [1940]
#
# ***********
# Bobby Ferguson (no trips)
# ***********
#
# ***********
# Bobby Gay (no trips)
# ***********
#
# ***********
# Bobby Gordon (no trips)
# ***********
#
# ***********
# Bobby Grant (no trips)
# ***********
#
# ***********
# Bobby Hayes (no trips)
# ***********
#
# ***********
# Bobby Johnson (no trips)
# ***********
#
# ***********
# Bobby Jones (no trips)
# ***********
#
# ***********
# Bobby Kork (no trips)
# ***********
#
# ***********
# Bobby La Rue
# ***********
# Bobby La Rue did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby La Rue did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby La Rue did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby La Rue did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# in 1934, Bobby La Rue traveled from Pennsylvania to California
# in 1935, Bobby La Rue traveled from California to
# - California
# Pennsylvania
# Arizona
# Ohio
# in 1936, Bobby La Rue traveled from Pennsylvania to
# - Michigan
# Ohio
# Bobby La Rue did not travel in 1937 but we will assume that they stayed in their last location (Ohio) since 1936. --> means we have to fill out [1937]
# Bobby La Rue did not travel in 1938 but we will assume that they stayed in their last location (Ohio) since 1936. --> means we have to fill out [1937, 1938]
# Bobby La Rue did not travel in 1939 but we will assume that they stayed in their last location (Ohio) since 1936. --> means we have to fill out [1937, 1938, 1939]
# Bobby La Rue did not travel in 1940 but we will assume that they stayed in their last location (Ohio) since 1936. --> means we have to fill out [1937, 1938, 1939, 1940]
#
# ***********
# Bobby Lane (no trips)
# ***********
#
# ***********
# Bobby Leonard (no trips)
# ***********
#
# ***********
# Bobby McNeer (no trips)
# ***********
#
# ***********
# Bobby Mitchell (no trips)
# ***********
#
# ***********
# Bobby Morris (no trips)
# ***********
#
# ***********
# Bobby Norman (no trips)
# ***********
#
# ***********
# Bobby Royce (no trips)
# ***********
#
# ***********
# Bobby Stevens (no trips)
# ***********
#
# ***********
# Bobby Sullivan
# ***********
# Bobby Sullivan did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Sullivan did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Sullivan did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Sullivan did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Bobby Sullivan did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# ...
#
# ***********
# Ted Shaw (no trips)
# ***********
#
# ***********
# Teddy Cappy
# ***********
# Teddy Cappy did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# Teddy Cappy did not travel in 1938 but we looked backwards and saw that we do not have a previously recorded trip
# in 1939, Teddy Cappy was only found in Florida
# Teddy Cappy did not travel in 1940 but we will assume that they stayed in their last location (Florida) since 1939. --> means we have to fill out [1940]
#
# ***********
# Teddy Hayes (no trips)
# ***********
#
# ***********
# Teddy Keller (no trips)
# ***********
#
# ***********
# Teddy — (no trips)
# ***********
#
# ***********
# Terry La Monte
# ***********
# Terry La Monte did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Terry La Monte did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# in 1938, Terry La Monte traveled from Ohio to Minnesota
# Terry La Monte did not travel in 1939 but we will assume that they stayed in their last location (Minnesota) since 1938. --> means we have to fill out [1939]
# Terry La Monte did not travel in 1940 but we will assume that they stayed in their last location (Minnesota) since 1938. --> means we have to fill out [1939, 1940]
#
# ***********
# Terry Lane (no trips)
# ***********
#
# ***********
# Terry Phillips (no trips)
# ***********
#
# ***********
# Terry Stone (no trips)
# ***********
#
# ***********
# Terry Tremaine
# ***********
# Terry Tremaine did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Terry Tremaine did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# in 1937, Terry Tremaine traveled from Pennsylvania to Connecticut
# Terry Tremaine did not travel in 1938 but we will assume that they stayed in their last location (Connecticut) since 1937. --> means we have to fill out [1938]
# Terry Tremaine did not travel in 1939 but we will assume that they stayed in their last location (Connecticut) since 1937. --> means we have to fill out [1938, 1939]
# Terry Tremaine did not travel in 1940 but we will assume that they stayed in their last location (Connecticut) since 1937. --> means we have to fill out [1938, 1939, 1940]
#
# ***********
# Tess Russell (no trips)
# ***********
#
# ***********
# Tex Hendricks
# ***********
# Tex Hendricks did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Tex Hendricks did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Tex Hendricks did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Tex Hendricks did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Tex Hendricks did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Tex Hendricks did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# in 1936, Tex Hendricks was only found in New York
# Tex Hendricks did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1936. --> means we have to fill out [1937]
# Tex Hendricks did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1936. --> means we have to fill out [1937, 1938]
# in 1939, Tex Hendricks was only found in Florida
# Tex Hendricks did not travel in 1940 but we will assume that they stayed in their last location (Florida) since 1939. --> means we have to fill out [1940]
#
# ***********
# The Mystery Dancer (no trips)
# ***********
#
# ***********
# Thelma Lee (no trips)
# ***********
#
# ***********
# Theodore Coppi (no trips)
# ***********
#
# ***********
# Thetis Storey (no trips)
# ***********
#
# ***********
# Thomas Martin (no trips)
# ***********
#
# ***********
# Thompson Twin 1 (no trips)
# ***********
#
# ***********
# Thompson Twin 2 (no trips)
# ***********
#
# ***********
# Tiny Kingsmore (no trips)
# ***********
#
# ***********
# Titanic Kit Russell (no trips)
# ***********
#
# ***********
# Toby Waddell (no trips)
# ***********
#
# ***********
# Tom Hose (no trips)
# ***********
#
# ***********
# Tom Martelle (no trips)
# ***********
#
# ***********
# Tommy Mann (no trips)
# ***********
#
# ***********
# Tony Collins (no trips)
# ***********
#
# ***********
# Tony Karol (no trips)
# ***********
#
# ***********
# Toots (no trips)
# ***********
#
# ***********
# Val Rai (no trips)
# ***********
#
# ***********
# Val Turek (no trips)
# ***********
#
# ***********
# Val Varr (no trips)
# ***********
#
# ***********
# Valda Gray
# ***********
# Valda Gray did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Valda Gray did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Valda Gray did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Valda Gray did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Valda Gray did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Valda Gray did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# in 1936, Valda Gray was only found in Illinois
# in 1937, Valda Gray was only found in Illinois
# in 1938, Valda Gray was only found in Illinois
# in 1939, Valda Gray was only found in Illinois
# Valda Gray did not travel in 1940 but we will assume that they stayed in their last location (Illinois) since 1939. --> means we have to fill out [1940]
#
# ***********
# Vera Mazzie (no trips)
# ***********
#
# ***********
# Verne Valdez
# ***********
# Verne Valdez did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Verne Valdez did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Verne Valdez did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Verne Valdez did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Verne Valdez did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Verne Valdez traveled from California to
# - California
# Ohio
# Pennsylvania
# in 1936, Verne Valdez traveled from Pennsylvania to
# - Michigan
# Ohio
# Maryland
# in 1937, Verne Valdez traveled from Ohio to
# - California
# Ohio
# Texas
# Maryland
# in 1938, Verne Valdez traveled from Texas to Washington
# in 1939, Verne Valdez traveled from Washington to California
# Verne Valdez did not travel in 1940 but we will assume that they stayed in their last location (California) since 1939. --> means we have to fill out [1940]
#
# ***********
# Vincent McFarland (no trips)
# ***********
#
# ***********
# Vincent Reid (no trips)
# ***********
#
# ***********
# Violet Clements (no trips)
# ***********
#
# ***********
# Wallace Reed (no trips)
# ***********
#
# ***********
# Wallie Groff (no trips)
# ***********
#
# ***********
# Wally Brennan (no trips)
# ***********
#
# ***********
# Wally Thompson (no trips)
# ***********
#
# ***********
# Walter Hart
# ***********
# Walter Hart did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1935 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1936 but we looked backwards and saw that we do not have a previously recorded trip
# Walter Hart did not travel in 1937 but we looked backwards and saw that we do not have a previously recorded trip
# in 1938, Walter Hart was only found in California
# in 1939, Walter Hart was only found in California
# Walter Hart did not travel in 1940 but we will assume that they stayed in their last location (California) since 1939. --> means we have to fill out [1940]
#
# ***********
# Walter McDonald
# ***********
# Walter McDonald did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Walter McDonald did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Walter McDonald did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# in 1933, Walter McDonald was only found in Florida
# Walter McDonald did not travel in 1934 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934]
# Walter McDonald did not travel in 1935 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935]
# Walter McDonald did not travel in 1936 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935, 1936]
# Walter McDonald did not travel in 1937 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937]
# Walter McDonald did not travel in 1938 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938]
# Walter McDonald did not travel in 1939 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939]
# Walter McDonald did not travel in 1940 but we will assume that they stayed in their last location (Florida) since 1933. --> means we have to fill out [1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# Walter Munde (no trips)
# ***********
#
# ***********
# Weldon Short (no trips)
# ***********
#
# ***********
# Wesley Davis
# ***********
# Wesley Davis did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# Wesley Davis did not travel in 1931 but we looked backwards and saw that we do not have a previously recorded trip
# Wesley Davis did not travel in 1932 but we looked backwards and saw that we do not have a previously recorded trip
# Wesley Davis did not travel in 1933 but we looked backwards and saw that we do not have a previously recorded trip
# Wesley Davis did not travel in 1934 but we looked backwards and saw that we do not have a previously recorded trip
# in 1935, Wesley Davis traveled from Louisiana to Illinois
# in 1936, Wesley Davis traveled from Illinois to Wisconsin
# Wesley Davis did not travel in 1937 but we will assume that they stayed in their last location (Wisconsin) since 1936. --> means we have to fill out [1937]
# Wesley Davis did not travel in 1938 but we will assume that they stayed in their last location (Wisconsin) since 1936. --> means we have to fill out [1937, 1938]
# Wesley Davis did not travel in 1939 but we will assume that they stayed in their last location (Wisconsin) since 1936. --> means we have to fill out [1937, 1938, 1939]
# Wesley Davis did not travel in 1940 but we will assume that they stayed in their last location (Wisconsin) since 1936. --> means we have to fill out [1937, 1938, 1939, 1940]
#
# ***********
# Wilkie Mason (no trips)
# ***********
#
# ***********
# William Harris
# ***********
# William Harris did not travel in 1930 but we looked backwards and saw that we do not have a previously recorded trip
# in 1931, William Harris was only found in New York
# William Harris did not travel in 1932 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932]
# William Harris did not travel in 1933 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933]
# William Harris did not travel in 1934 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934]
# William Harris did not travel in 1935 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935]
# William Harris did not travel in 1936 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935, 1936]
# William Harris did not travel in 1937 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935, 1936, 1937]
# William Harris did not travel in 1938 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935, 1936, 1937, 1938]
# William Harris did not travel in 1939 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939]
# William Harris did not travel in 1940 but we will assume that they stayed in their last location (New York) since 1931. --> means we have to fill out [1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940]
#
# ***********
# William Johnson (no trips)
# ***********
#
# ***********
# William Lee Becker (no trips)
# ***********
#
# ***********
# Yvonne — (no trips)
# ***********
#
# ***********
# Zalman (no trips)
# ***********
#
# ***********
# [Harold Shinn] (no trips)
# ***********
#
# ***********
# — Brennan (no trips)
# ***********
#
# ***********
# — Dion (no trips)
# ***********
#
# ***********
# — Enesco (no trips)
# ***********
#
# ***********
# — Marion (no trips)
# ***********
#
# ***********
# — Satch (no trips)
# ***********
#
# ***********
# — Satchell (no trips)
# ***********

# %%
# Reorganize into source - target:

# source_targets = {}
padded_travels_performers = {}
inferred_travels = {}

for performer, travels in padded_travels.items():
    for year, data in travels.items():
        data['to'] = [x for x in data['to'] if x]
        data['from'] = data['from']
        inferred = data['inferred']
        if data['from'] and len(data['to']):
            print(performer, year, data['to'], data['from'])
            last_to = data['to'][-1] # select only the last one - no travels inside the year counts - only when a performer appeared at the beginnning of the year and at the end of it...

            if inferred:
                if not data['from'] in inferred_travels:
                    inferred_travels[data['from']] = {}
                if not last_to in inferred_travels[data['from']]:
                    inferred_travels[data['from']][last_to] = {}
                if not year in inferred_travels[data['from']][last_to]:
                    inferred_travels[data['from']][last_to][year] = []
                inferred_travels[data['from']][last_to][year].append(performer)
                inferred_travels[data['from']][last_to][year] = list(set(inferred_travels[data['from']][last_to][year]))


            #if not data['from'] in source_targets:
            #    source_targets[data['from']] = {}
            #if not last_to in source_targets[data['from']]:
            #    source_targets[data['from']][last_to] = {}
            #if not year in source_targets[data['from']][last_to]:
            #    source_targets[data['from']][last_to][year] = 0
            #source_targets[data['from']][last_to][year] += 1
            
            slugified_from = data['from'] # could slugify here
            slugified_last_to = last_to # could slugify here
            if not slugified_from in padded_travels_performers:
                padded_travels_performers[slugified_from] = {}
            if not slugified_last_to in padded_travels_performers[slugified_from]:
                padded_travels_performers[slugified_from][slugified_last_to] = {}
            if not year in padded_travels_performers[slugified_from][slugified_last_to]:
                padded_travels_performers[slugified_from][slugified_last_to][year] = []
            padded_travels_performers[slugified_from][slugified_last_to][year].append(performer)
            padded_travels_performers[slugified_from][slugified_last_to][year] = list(set(padded_travels_performers[slugified_from][slugified_last_to][year]))
        else:
            pass # print(f'no recorded data for {performer} in {year}')
# Out:
# Adrian Ames 1930 ['New York'] New York
# Adrian Ames 1931 ['New York'] New York
# Adrian Ames 1932 ['New York'] New York
# Adrian Ames 1933 ['New York'] New York
# Adrian Ames 1934 ['New York'] New York
# Adrian Ames 1935 ['New York'] New York
# Adrian Ames 1936 ['New York'] New York
# Adrian Ames 1937 ['New York'] New York
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'La Belle Rose',
#     'Frances Fay',
#     'Niles Marsh',
#     'Arthur G. West',
#     'G. Doran',
#     'Jean Malin',
#     'Olyn Landick',
#     'Arthur Budd',
#     'William Harris',
#     'Lester Lamont'],
#    1933: ['Billy Reed',
#     'Frank Doran',
#     'Max Lengel',
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'La Belle Rose',
#     'Frances Fay',
#     'Niles Marsh',
#     'Arthur G. West',
#     'G. Doran',
#     'Jack Mason',
#     'Olyn Landick',
#     'Arthur Budd',
#     'Jean Malin',
#     'William Harris',
#     'Lester Lamont'],
#    1934: ['Lyle Mack',
#     'Jackie Maye',
#     'Al DeMarco',
#     'Bobbie La Marr',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Gene Renee',
#     'Billy Reed',
#     'Lucian',
#     'Lyle Page',
#     'Arica Wild',
#     'Mickey Nelson',
#     'Jackie Giggles',
#     'Gene Casali',
#     'William Harris',
#     'Lester Lamont',
#     'Frank Doran',
#     'Max Lengel',
#     'Bobby Dell',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Johnny Kaye',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Jacquette La Marr',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Sepia Mae West'],
#    1935: ['Al DeMarco',
#     'Bobbie La Marr',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Billy Reed',
#     'Lucian',
#     'Lyle Page',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Bobby Dell',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Johnny Mangum',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri',
#     'Sepia Mae West'],
#    1936: ['Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Johnny Mangum',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1937: ['Jackie Maye',
#     'Merry Pickford',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1938: ['Jackie Maye',
#     'Merry Pickford',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1939: ['Merry Pickford',
#     'Bobby Sullivan',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'George Kelly',
#     'Billy Reed',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Gorda Davies',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1940: ['Merry Pickford',
#     'Bobby Sullivan',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'George Kelly',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Rae Bourbon',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Gorda Davies',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Pep Murray',
#     'Jimmie Sheri']},
#   'Pennsylvania': {1936: ['Al DeMarco', 'Jean Osborne', 'Nicki Gallucci'],
#    1934: ['Mickey Dell', 'Ed-Na Link'],
#    1935: ['Gene Casali', 'Gene Renee', 'Merry Pickford']},
#   'New Jersey': {1935: ['Arica Wild', 'E. Russell'], 1933: ['Jackie Lee']},
#   'Texas': {1935: ['Boots Lavana', 'Billie Brannon']},
#   'Kentucky': {1935: ['Billy Hayes']},
#   'Florida': {1938: ['Bobbie La Marr'], 1934: ['Leon La Verde']},
#   'Michigan': {1939: ['Bobby Dell'], 1935: ['Danny King']},
#   'Ohio': {1935: ['Lyle Mack',
#     'Danny Brown',
#     'Reggie "Dolly" Windsor',
#     'Del Le Roy',
#     'Jerry Clayton']},
#   'Maryland': {1935: ['Jackie Adams', 'Edmund Link'],
#    1934: ['Jackie Adams', 'Nicki Gallucci'],
#    1936: ['Lester Lamont']},
#   'Massachusetts': {1935: ['Jackie Maye']},
#   'California': {1939: ['Jean Barrios']},
#   'Illinois': {1931: ['Leon La Verde', 'Karyl Norman'],
#    1936: ['Lyle Page', 'Sepia Mae West'],
#    1938: ['Sandra']},
#   'Missouri': {1937: ['Lanny Brice']},
#   'North Carolina': {1935: ['Roni Warren']}},
#  'Illinois': {'Illinois': {1933: ['Billie Russell',
#     'George Oliver',
#     'Billy Richards',
#     'Billie Brannon',
#     'Al Benson'],
#    1934: ['Al Benson', 'Billie Russell', 'George Oliver'],
#    1935: ['Al Benson', 'Billie Russell', 'George Oliver'],
#    1936: ['Billie Russell',
#     'George Oliver',
#     'Valda Gray',
#     'Ralph Gilbert',
#     'Al Benson',
#     'Gypsy Dolan'],
#    1937: ['Billie Russell',
#     'Joanne Crawford',
#     'George Oliver',
#     'Valda Gray',
#     'Jean La Rue',
#     'Ralph Gilbert',
#     'Al Benson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1938: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1939: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Alice White',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Dixie Lee',
#     'Sandra',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1940: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Alice White',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Dixie Lee',
#     'Sandra',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1932: ['Leon La Verde'],
#    1931: ['Sepia Gloria Swanson']},
#   'New York': {1934: ['Sepia Gloria Swanson', 'Billie Brannon'],
#    1933: ['Bobbie La Marr', 'Leon La Verde', 'Lyle Page']},
#   'Pennsylvania': {1937: ['Dixie Lee'],
#    1936: ['Petite Swanson', 'Peaches Browning']},
#   'Louisiana': {1934: ['Gene Dana']},
#   'Minnesota': {1938: ['Jackie Starr', 'Gita Gilmore']},
#   'Wisconsin': {1936: ['Johnny Blease', 'Wesley Davis'],
#    1933: ['Johnny Mangum']},
#   'California': {1932: ['Karyl Norman']},
#   'Michigan': {1932: ['Sepia Gloria Swanson']}},
#  'Pennsylvania': {'Pennsylvania': {1937: ['Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Bobby Dell',
#     'Dixie DeLane',
#     'Gene Renee',
#     'Nicki Gallucci',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link'],
#    1938: ['Clara Bow',
#     'Danny Brown',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Bobby Dell',
#     'Dixie DeLane',
#     'Gene Renee',
#     'Nicki Gallucci',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link'],
#    1939: ['Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Lloyd Woods',
#     'Dixie DeLane',
#     'Gene Casali',
#     'Gene Renee',
#     'Ed-Na Link'],
#    1940: ['Lucian',
#     'Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Sunny La Ray',
#     'Dixie DeLane',
#     'Peppy Carman',
#     'Gene Renee',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link'],
#    1936: ['Clara Bow',
#     'Bobby Dell',
#     'Lloyd Woods',
#     'Dixie DeLane',
#     'Gene Casali',
#     'Gene Renee',
#     'Francis Renault',
#     'Ed-Na Link'],
#    1934: ['Dixie DeLane'],
#    1935: ['Johnny Kaye',
#     'Dixie DeLane',
#     'Peggy Joyce',
#     'Manhattan Pearl',
#     'Ed-Na Link']},
#   'Kentucky': {1935: ['Fay Norman', 'Alberta Vaughn']},
#   'Michigan': {1939: ['Billy Brill',
#     'Danny Brown',
#     'Francis Renault',
#     'Del Le Roy'],
#    1935: ['Connie Walsh', 'Jean Darling', 'Jackie Lane']},
#   'New York': {1937: ['Bobbie La Marr'],
#    1935: ['Lester Lamont'],
#    1936: ['Manhattan Pearl', 'Merry Pickford'],
#    1934: ['Merry Pickford']},
#   'California': {1934: ['Bobby La Rue'], 1932: ['Jean Barrios']},
#   'Ohio': {1936: ['Bobby La Rue', 'Johnny Kaye'],
#    1935: ['Mickey Nelson', 'Jacquette La Marr', 'Dixie Dixon']},
#   'Illinois': {1938: ['Dixie Lee'],
#    1936: ['Joanne Crawford'],
#    1937: ['Petite Swanson', 'Peaches Browning']},
#   'Iowa': {1931: ['Francis Renault']},
#   'Alabama': {1932: ['Francis Renault']},
#   'Massachusetts': {1937: ['Francis Renault']},
#   'Louisiana': {1934: ['Georgie Kaye']},
#   'Missouri': {1937: ['Lena Rivers'], 1936: ['Peggy Joyce']},
#   'Maryland': {1935: ['Mickey Dell'], 1936: ['Verne Valdez']},
#   'Connecticut': {1937: ['Terry Tremaine']}},
#  'Michigan': {'Michigan': {1936: ['Alberta Vaughn', 'Danny King'],
#    1940: ['Danny Brown',
#     'Gita Gilmore',
#     'Bobby Dell',
#     'Jackie Starr',
#     'Mickey Nelson',
#     'Tangara',
#     'Eddie Morton',
#     'Karyl Norman',
#     'Jean La Monte',
#     'Billy Hayes',
#     'Jackie Lane',
#     'Del Le Roy',
#     'Frankie Stroud',
#     'Gene Dana',
#     'Danny King',
#     'Francis Renault',
#     'Billy Brill'],
#    1937: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Frankie Stroud',
#     'Del Le Roy',
#     'Danny King'],
#    1938: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Jackie Lane',
#     'Frankie Stroud',
#     'Del Le Roy',
#     'Danny King'],
#    1939: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Jackie Lane',
#     'Frankie Stroud',
#     'Danny King']},
#   'Minnesota': {1937: ['Funny Fanny', 'Alberta Vaughn']},
#   'Ohio': {1937: ['Billy Hayes'], 1936: ['Jackie Lane']},
#   'Kentucky': {1936: ['Connie Walsh', 'Carlo Levins']},
#   'Louisiana': {1935: ['Doyle Mack', 'Frankie Stroud']},
#   'New York': {1934: ['Jackie Lane']},
#   'Pennsylvania': {1934: ['Jean Darling']},
#   'Indiana': {1936: ['Jean Darling']},
#   'Illinois': {1935: ['Ralph Gilbert'], 1933: ['Sepia Gloria Swanson']}},
#  'Minnesota': {'Wisconsin': {1938: ['Alberta Vaughn']},
#   'Michigan': {1939: ['Billy Hayes', 'Gita Gilmore']},
#   'Minnesota': {1938: ['Frances Lee'],
#    1939: ['Terry La Monte', 'Frances Lee'],
#    1940: ['Terry La Monte', 'Frances Lee']}},
#  'Wisconsin': {'Wisconsin': {1939: ['Alberta Vaughn',
#     'Funny Fanny',
#     'Wesley Davis',
#     'Frances David',
#     'Neil Dornay',
#     'Johnny Blease'],
#    1940: ['Alberta Vaughn',
#     'Funny Fanny',
#     'Wesley Davis',
#     'Frances David',
#     'Neil Dornay',
#     'Johnny Blease'],
#    1936: ['Neil Dornay', 'Frances David'],
#    1937: ['Neil Dornay', 'Frances David', 'Johnny Blease', 'Wesley Davis'],
#    1938: ['Neil Dornay', 'Frances David', 'Johnny Blease', 'Wesley Davis'],
#    1933: ['Leon Fredericks'],
#    1934: ['Neil Dornay'],
#    1935: ['Neil Dornay']},
#   'New York': {1930: ['Frank Doran',
#     'Arthur G. West',
#     'G. Doran',
#     'Francis Renault'],
#    1934: ['Johnny Mangum']},
#   'Florida': {1933: ['Billy "Senorita" Herrera', 'Gene Dana', 'Jean Russell']},
#   'Louisiana': {1934: ['Don Rand', 'Eddie Morton', 'Frankie Stroud']},
#   'Michigan': {1934: ['Doyle Mack']},
#   'Alabama': {1933: ['Francis Renault']},
#   'California': {1934: ['Leon Fredericks']},
#   'Illinois': {1937: ['Nina Mae McKinney']},
#   'Maryland': {1934: ['Ralph Gilbert']}},
#  'New Jersey': {'New York': {1933: ['Arica Wild',
#     'Jackie Adams',
#     'Billie Davis'],
#    1934: ['Danny Brown']},
#   'New Jersey': {1936: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1937: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1938: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1939: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1940: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1934: ['Jackie Lee'],
#    1935: ['Jackie Lee']},
#   'California': {1934: ['Carl Clewis']},
#   'Pennsylvania': {1933: ['Dixie DeLane']},
#   'Illinois': {1937: ['Lyle Page']}},
#  'Missouri': {'Ohio': {1935: ['Art West'], 1936: ['Doyle Mack']},
#   'California': {1938: ['Billie Beryl', 'Rae Bourbon'],
#    1939: ['Francis Blair'],
#    1937: ['Johnny Mangum'],
#    1935: ['Rae Bourbon']},
#   'Missouri': {1937: ['Donald Grey',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1938: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1939: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1940: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1936: ['Donald Grey', 'Eli Madlof'],
#    1935: ['Eli Madlof']},
#   'Texas': {1935: ['Lena Rivers', 'Billy Richards']},
#   'Louisiana': {1935: ['Bobbie Bell']},
#   'Wisconsin': {1935: ['Frances David']},
#   'Michigan': {1936: ['Frankie Stroud']},
#   'Illinois': {1935: ['Gypsy Dolan']},
#   'Colorado': {1937: ['Pepper Cortez']}},
#  'Ohio': {'Ohio': {1936: ['George Hayes',
#     'Lyle Mack',
#     'Danny Brown',
#     'Leon La Verde',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Li Kar',
#     'Art West',
#     'Jerry Clayton'],
#    1937: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Leon La Verde',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Jerry Clayton',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1938: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1939: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1940: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1935: ['Li Kar', 'Leon La Verde']},
#   'Missouri': {1937: ['Billie Beryl'], 1934: ['Bobbie Bell']},
#   'Minnesota': {1938: ['Billy Hayes', 'Terry La Monte'],
#    1937: ['Frances Lee']},
#   'California': {1934: ['Billy Richards'],
#    1938: ['Leon La Verde'],
#    1937: ['Li Kar']},
#   'Louisiana': {1936: ['Billy Rohmer']},
#   'New York': {1936: ['Bobbie La Marr', 'Karyl Norman', 'Jackie Maye'],
#    1934: ['Boots Lavana']},
#   'Kentucky': {1936: ['Jacquette La Marr', 'Chickie Mears']},
#   'Colorado': {1937: ['Danny Brown']},
#   'Michigan': {1936: ['Funny Fanny', 'Mickey Nelson', 'Tangara', 'Del Le Roy'],
#    1937: ['Jackie Lane'],
#    1939: ['Jackie Starr', 'Karyl Norman']},
#   'Tennessee': {1936: ['Fay Norman']},
#   'New Jersey': {1938: ['Francis Renault']},
#   'Wisconsin': {1938: ['Funny Fanny']},
#   'Illinois': {1937: ['Jackie Starr', 'Gita Gilmore']},
#   'Massachusetts': {1935: ['Karyl Norman']},
#   'Maryland': {1937: ['Verne Valdez']}},
#  'Florida': {'Maryland': {1934: ['Billy "Senorita" Herrera', 'Babe Allen']},
#   'Florida': {1939: ['Jean Russell',
#     'Tex Hendricks',
#     'Gene Russell',
#     'Paul Russell',
#     'Bobbie La Marr',
#     'Teddy Cappy',
#     'Norman Lewis',
#     'Blackie Dennis',
#     'Johnny Mangum',
#     'Nicki Gallucci',
#     'Walter McDonald',
#     'Billy Rohmer',
#     'Pat Clayton',
#     'Lynn & Johnson',
#     'Bill Kennedy'],
#    1940: ['Billy "Senorita" Herrera',
#     'Jean Russell',
#     'Tex Hendricks',
#     'Gene Russell',
#     'Paul Russell',
#     'Bobbie La Marr',
#     'Teddy Cappy',
#     'Norman Lewis',
#     'Blackie Dennis',
#     'Johnny Mangum',
#     'Nicki Gallucci',
#     'Walter McDonald',
#     'Billy Rohmer',
#     'Pat Clayton',
#     'Lynn & Johnson',
#     'Bill Kennedy'],
#    1933: ['Donald Grey', 'Walter McDonald', 'Gene Russell'],
#    1938: ['Gene Dana', 'Walter McDonald', 'Jean Russell', 'Gene Russell'],
#    1934: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1935: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1936: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1937: ['Jean Russell', 'Walter McDonald', 'Gene Russell']},
#   'Louisiana': {1934: ['Billy Rohmer']},
#   'California': {1934: ['Donald Grey'], 1939: ['Jackie Maye']},
#   'Michigan': {1939: ['Gene Dana']},
#   'Pennsylvania': {1939: ['Lucian', 'Sunny La Ray', 'Peppy Carman']}},
#  'Maryland': {'Maryland': {1935: ['Billy "Senorita" Herrera',
#     'Bert Sherry',
#     'Babe Allen'],
#    1936: ['Bert Sherry', 'Mickey Dell', 'Edmund Link', 'Babe Allen'],
#    1937: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1938: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1939: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1940: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1934: ['Mother Smother/Sepia Marlene Dietrich', 'Bert Sherry']},
#   'Illinois': {1936: ['Dixie Lee']},
#   'New York': {1936: ['Jackie Adams'],
#    1935: ['Mother Smother/Sepia Marlene Dietrich', 'Nicki Gallucci']},
#   'Ohio': {1935: ['Larry West']}},
#  'California': {'California': {1939: ['Johnny David',
#     'Leon La Verde',
#     'Billie Beryl',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Jerry Clayton',
#     'Niles Marsh',
#     'Walter Hart',
#     'Li Kar',
#     'Don La Rue',
#     'Carl Clewis'],
#    1940: ['Jean Barrios',
#     'Johnny David',
#     'Leon La Verde',
#     'Jackie Maye',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Francis Blair',
#     'Niles Marsh',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Verne Valdez',
#     'Jerry Clayton',
#     'Billie Beryl',
#     'Walter Hart',
#     'Li Kar',
#     'Don La Rue',
#     'Carl Clewis'],
#    1938: ['Billy "Senorita" Herrera',
#     'Jean Barrios',
#     'Johnny David',
#     'Don La Rue',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Walter Hart',
#     'Li Kar',
#     'Jerry Clayton',
#     'Carl Clewis'],
#    1935: ['Jean Barrios',
#     'Rocky twins',
#     'Don La Rue',
#     'Carl Clewis',
#     'Leon Fredericks'],
#    1936: ['Jean Barrios',
#     'Rocky twins',
#     'Rae Bourbon',
#     'Don La Rue',
#     'Carl Clewis'],
#    1937: ['Jean Barrios',
#     'Johnny David',
#     'Rocky twins',
#     'Rae Bourbon',
#     'Don La Rue',
#     'Carl Clewis'],
#    1932: ['Neil Dornay', 'Rocky twins', 'Don La Rue'],
#    1933: ['Jean Barrios', 'Rocky twins', 'Don La Rue'],
#    1934: ['Jean Barrios', 'Rocky twins', 'Don La Rue'],
#    1930: ['Jean Barrios'],
#    1931: ['Rae Bourbon']},
#   'Florida': {1939: ['Billy "Senorita" Herrera'], 1938: ['Johnny Mangum']},
#   'Ohio': {1935: ['Bobby La Rue']},
#   'Missouri': {1935: ['Donald Grey'], 1936: ['Leon Fredericks']},
#   'Pennsylvania': {1931: ['Jean Barrios'], 1935: ['Verne Valdez']},
#   'Texas': {1935: ['Johnny David']},
#   'New York': {1933: ['Karyl Norman'], 1939: ['Rae Bourbon']},
#   'Wisconsin': {1933: ['Neil Dornay']},
#   'Utah': {1932: ['Rae Bourbon']}},
#  'Texas': {'Missouri': {1936: ['Billie Brannon'], 1937: ['Phil Craig']},
#   'Pennsylvania': {1936: ['Billy "Senorita" Herrera']},
#   'Nevada': {1936: ['Billy Richards']},
#   'Ohio': {1935: ['Billy Rohmer'],
#    1936: ['Bobbie Bell', 'Lena Rivers', 'Gita Gilmore']},
#   'Texas': {1936: ['Phil Craig', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1937: ['Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1938: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1939: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1940: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1935: ['Eddie Morton',
#     'Georgie Kaye',
#     'Jean Evol',
#     'Don Rand',
#     'Gene Dana'],
#    1932: ['Jean Evol'],
#    1933: ['Jean Evol'],
#    1934: ['Jean Evol']},
#   'Kentucky': {1936: ['Don Rand']},
#   'Michigan': {1936: ['Eddie Morton']},
#   'Louisiana': {1936: ['Gene Dana']},
#   'Florida': {1937: ['Gene Dana']},
#   'California': {1936: ['Johnny David']},
#   'Washington': {1938: ['Verne Valdez']}},
#  'Washington': {'California': {1937: ['Billy "Senorita" Herrera'],
#    1939: ['Verne Valdez']},
#   'Nevada': {1936: ['Francis Blair']},
#   'Texas': {1937: ['Johnny Kaye']}},
#  'Kentucky': {'Kentucky': {1936: ['Billy Hayes'],
#    1937: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1938: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1939: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1940: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins']}},
#  'Nevada': {'Nevada': {1937: ['Billy Richards', 'Francis Blair'],
#    1938: ['Billy Richards', 'Francis Blair'],
#    1939: ['Billy Richards'],
#    1940: ['Billy Richards']}},
#  'Louisiana': {'Louisiana': {1937: ['Billy Rohmer'], 1938: ['Billy Rohmer']},
#   'Illinois': {1935: ['Wesley Davis']}},
#  'Tennessee': {'Missouri': {1937: ['Fay Norman']}},
#  'West Virginia': {'Wyoming': {1934: ['Francis Renault']}},
#  'Wyoming': {'New Jersey': {1935: ['Francis Renault']},
#   'Michigan': {1939: ['Jean La Monte']}},
#  'Indiana': {'Indiana': {1937: ['Jean Darling'],
#    1938: ['Jean Darling'],
#    1939: ['Jean Darling'],
#    1940: ['Jean Darling']}},
#  'Colorado': {'Colorado': {1938: ['Pepper Cortez'],
#    1939: ['Pepper Cortez'],
#    1940: ['Pepper Cortez']}},
#  'Utah': {'New York': {1933: ['Rae Bourbon']},
#   'Florida': {1934: ['Rae Bourbon']}},
#  'North Carolina': {'Connecticut': {1936: ['Roni Warren']}},
#  'Connecticut': {'Connecticut': {1937: ['Roni Warren'],
#    1938: ['Terry Tremaine'],
#    1939: ['Terry Tremaine'],
#    1940: ['Terry Tremaine']},
#   'New York': {1938: ['Roni Warren']}}}

# %%
years = range(1930,1941)
padded_travels_performers = {source: {target: {year: __.get(year, []) for year in years} for target, __ in _.items()} for source, _ in padded_travels_performers.items()}

# %%
new = {}
for source, _ in padded_travels_performers.items():
    if not source in new:
        new[source] = {}
    for target, __ in _.items():
        if not target in new[source]:
            new[source][target] = {}
        for year, performers in __.items():
            if not year in new[source][target]:
                new[source][target][year] = []
            if not performers:
                if source == target:
                    new[source][target][year] = ['filler']
            else:
                new[source][target][year] = performers

for source, _ in padded_travels_performers.items():
    for target, __ in _.items():
        try:
            new[source][source]
        except KeyError:
            new[source][source] = {year: ['filler'] for year in range(1930, 1941)}
    
padded_travels_performers = new.copy()

padded_travels_performers
# Out:
# {'New York': {'New York': {1930: ['Billy Reed',
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'Karyl Norman',
#     'Frances Fay',
#     'Jean Malin',
#     'Arthur Budd',
#     'Lester Lamont'],
#    1931: ['Billy Reed',
#     'Frank Doran',
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'Frances Fay',
#     'Arthur Budd',
#     'Arthur G. West',
#     'G. Doran',
#     'Jean Malin',
#     'Niles Marsh',
#     'William Harris',
#     'Lester Lamont'],
#    1932: ['Billy Reed',
#     'Frank Doran',
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'La Belle Rose',
#     'Frances Fay',
#     'Niles Marsh',
#     'Arthur G. West',
#     'G. Doran',
#     'Jean Malin',
#     'Olyn Landick',
#     'Arthur Budd',
#     'William Harris',
#     'Lester Lamont'],
#    1933: ['Billy Reed',
#     'Frank Doran',
#     'Max Lengel',
#     'Frances Dunn',
#     'Jackie Maye',
#     'Adrian Ames',
#     'Jarahal',
#     'La Belle Rose',
#     'Frances Fay',
#     'Niles Marsh',
#     'Arthur G. West',
#     'G. Doran',
#     'Jack Mason',
#     'Olyn Landick',
#     'Arthur Budd',
#     'Jean Malin',
#     'William Harris',
#     'Lester Lamont'],
#    1934: ['Lyle Mack',
#     'Jackie Maye',
#     'Al DeMarco',
#     'Bobbie La Marr',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Gene Renee',
#     'Billy Reed',
#     'Lucian',
#     'Lyle Page',
#     'Arica Wild',
#     'Mickey Nelson',
#     'Jackie Giggles',
#     'Gene Casali',
#     'William Harris',
#     'Lester Lamont',
#     'Frank Doran',
#     'Max Lengel',
#     'Bobby Dell',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Johnny Kaye',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Jacquette La Marr',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Sepia Mae West'],
#    1935: ['Al DeMarco',
#     'Bobbie La Marr',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Billy Reed',
#     'Lucian',
#     'Lyle Page',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Bobby Dell',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Johnny Mangum',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri',
#     'Sepia Mae West'],
#    1936: ['Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Johnny Mangum',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1937: ['Jackie Maye',
#     'Merry Pickford',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1938: ['Jackie Maye',
#     'Merry Pickford',
#     'Karyl Norman',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Lucian',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Tex Hendricks',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Niles Marsh',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1939: ['Merry Pickford',
#     'Bobby Sullivan',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'Manhattan Pearl',
#     'George Kelly',
#     'Billy Reed',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Gorda Davies',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Pep Murray',
#     'Jimmie Sheri'],
#    1940: ['Merry Pickford',
#     'Bobby Sullivan',
#     'Arthur G. West',
#     'James Lyons',
#     'Olyn Landick',
#     'George Kelly',
#     'Manhattan Pearl',
#     'Billy Reed',
#     'Jackie Giggles',
#     'Phil Black',
#     'William Harris',
#     'Frank Doran',
#     'Max Lengel',
#     'Dennis Griffin',
#     'Jarahal',
#     'Jackie Adams',
#     'Jerry Francis',
#     'Frances Fay',
#     'G. Doran',
#     'Jean Malin',
#     'Arthur Budd',
#     'Rae Bourbon',
#     'Billie Davis',
#     'Jackie Lorraine',
#     'Barbette',
#     'Gorda Davies',
#     'Roni Warren',
#     'Jabby Caruso',
#     'Frances Dunn',
#     'Adrian Ames',
#     'La Belle Rose',
#     'Harvey Lee',
#     'Mother Smother/Sepia Marlene Dietrich',
#     'Joe Johnson',
#     'Sepia Gloria Swanson',
#     'Billy West',
#     'Jack Mason',
#     'Pep Murray',
#     'Jimmie Sheri']},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Mickey Dell', 'Ed-Na Link'],
#    1935: ['Gene Casali', 'Gene Renee', 'Merry Pickford'],
#    1936: ['Al DeMarco', 'Jean Osborne', 'Nicki Gallucci'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New Jersey': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Jackie Lee'],
#    1934: [],
#    1935: ['Arica Wild', 'E. Russell'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Texas': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Boots Lavana', 'Billie Brannon'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Kentucky': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Billy Hayes'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Florida': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Leon La Verde'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Bobbie La Marr'],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Danny King'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Bobby Dell'],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Lyle Mack',
#     'Danny Brown',
#     'Reggie "Dolly" Windsor',
#     'Del Le Roy',
#     'Jerry Clayton'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Maryland': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Jackie Adams', 'Nicki Gallucci'],
#    1935: ['Jackie Adams', 'Edmund Link'],
#    1936: ['Lester Lamont'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Massachusetts': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Jackie Maye'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Jean Barrios'],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: ['Leon La Verde', 'Karyl Norman'],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Lyle Page', 'Sepia Mae West'],
#    1937: [],
#    1938: ['Sandra'],
#    1939: [],
#    1940: []},
#   'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Lanny Brice'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'North Carolina': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Roni Warren'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Illinois': {'Illinois': {1930: ['filler'],
#    1931: ['Sepia Gloria Swanson'],
#    1932: ['Leon La Verde'],
#    1933: ['Billie Russell',
#     'George Oliver',
#     'Billy Richards',
#     'Billie Brannon',
#     'Al Benson'],
#    1934: ['Al Benson', 'Billie Russell', 'George Oliver'],
#    1935: ['Al Benson', 'Billie Russell', 'George Oliver'],
#    1936: ['Billie Russell',
#     'George Oliver',
#     'Valda Gray',
#     'Ralph Gilbert',
#     'Al Benson',
#     'Gypsy Dolan'],
#    1937: ['Billie Russell',
#     'Joanne Crawford',
#     'George Oliver',
#     'Valda Gray',
#     'Jean La Rue',
#     'Ralph Gilbert',
#     'Al Benson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1938: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1939: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Alice White',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Dixie Lee',
#     'Sandra',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan'],
#    1940: ['Billie Russell',
#     'Joanne Crawford',
#     'Nina Mae McKinney',
#     'George Oliver',
#     'Bobbie Davis',
#     'Lyle Page',
#     'Alice White',
#     'Jean La Rue',
#     'Peaches Browning',
#     'Valda Gray',
#     'Dixie Lee',
#     'Sandra',
#     'Ralph Gilbert',
#     'Carol Lee',
#     'Al Benson',
#     'Petite Swanson',
#     'Sepia Mae West',
#     'Gypsy Dolan']},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Bobbie La Marr', 'Leon La Verde', 'Lyle Page'],
#    1934: ['Sepia Gloria Swanson', 'Billie Brannon'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Petite Swanson', 'Peaches Browning'],
#    1937: ['Dixie Lee'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Gene Dana'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Minnesota': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Jackie Starr', 'Gita Gilmore'],
#    1939: [],
#    1940: []},
#   'Wisconsin': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Johnny Mangum'],
#    1934: [],
#    1935: [],
#    1936: ['Johnny Blease', 'Wesley Davis'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: ['Karyl Norman'],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: ['Sepia Gloria Swanson'],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Pennsylvania': {'Pennsylvania': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['Dixie DeLane'],
#    1935: ['Johnny Kaye',
#     'Dixie DeLane',
#     'Peggy Joyce',
#     'Manhattan Pearl',
#     'Ed-Na Link'],
#    1936: ['Clara Bow',
#     'Bobby Dell',
#     'Lloyd Woods',
#     'Dixie DeLane',
#     'Gene Casali',
#     'Gene Renee',
#     'Francis Renault',
#     'Ed-Na Link'],
#    1937: ['Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Bobby Dell',
#     'Dixie DeLane',
#     'Gene Renee',
#     'Nicki Gallucci',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link'],
#    1938: ['Clara Bow',
#     'Danny Brown',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Bobby Dell',
#     'Dixie DeLane',
#     'Gene Renee',
#     'Nicki Gallucci',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link'],
#    1939: ['Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Lloyd Woods',
#     'Dixie DeLane',
#     'Gene Casali',
#     'Gene Renee',
#     'Ed-Na Link'],
#    1940: ['Lucian',
#     'Clara Bow',
#     'Jean Osborne',
#     'Al DeMarco',
#     'Sunny La Ray',
#     'Dixie DeLane',
#     'Peppy Carman',
#     'Gene Renee',
#     'Gene Casali',
#     'Lloyd Woods',
#     'Ed-Na Link']},
#   'Kentucky': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Fay Norman', 'Alberta Vaughn'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Connie Walsh', 'Jean Darling', 'Jackie Lane'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Billy Brill', 'Danny Brown', 'Francis Renault', 'Del Le Roy'],
#    1940: []},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Merry Pickford'],
#    1935: ['Lester Lamont'],
#    1936: ['Manhattan Pearl', 'Merry Pickford'],
#    1937: ['Bobbie La Marr'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: ['Jean Barrios'],
#    1933: [],
#    1934: ['Bobby La Rue'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Mickey Nelson', 'Jacquette La Marr', 'Dixie Dixon'],
#    1936: ['Bobby La Rue', 'Johnny Kaye'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Joanne Crawford'],
#    1937: ['Petite Swanson', 'Peaches Browning'],
#    1938: ['Dixie Lee'],
#    1939: [],
#    1940: []},
#   'Iowa': {1930: [],
#    1931: ['Francis Renault'],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Alabama': {1930: [],
#    1931: [],
#    1932: ['Francis Renault'],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Massachusetts': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Francis Renault'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Georgie Kaye'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Peggy Joyce'],
#    1937: ['Lena Rivers'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Maryland': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Mickey Dell'],
#    1936: ['Verne Valdez'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Connecticut': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Terry Tremaine'],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Michigan': {'Michigan': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['Alberta Vaughn', 'Danny King'],
#    1937: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Frankie Stroud',
#     'Del Le Roy',
#     'Danny King'],
#    1938: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Jackie Lane',
#     'Frankie Stroud',
#     'Del Le Roy',
#     'Danny King'],
#    1939: ['Tangara',
#     'Mickey Nelson',
#     'Eddie Morton',
#     'Jackie Lane',
#     'Frankie Stroud',
#     'Danny King'],
#    1940: ['Danny Brown',
#     'Gita Gilmore',
#     'Bobby Dell',
#     'Jackie Starr',
#     'Mickey Nelson',
#     'Tangara',
#     'Eddie Morton',
#     'Karyl Norman',
#     'Jean La Monte',
#     'Billy Hayes',
#     'Jackie Lane',
#     'Del Le Roy',
#     'Frankie Stroud',
#     'Gene Dana',
#     'Danny King',
#     'Francis Renault',
#     'Billy Brill']},
#   'Minnesota': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Funny Fanny', 'Alberta Vaughn'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Jackie Lane'],
#    1937: ['Billy Hayes'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Kentucky': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Connie Walsh', 'Carlo Levins'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Doyle Mack', 'Frankie Stroud'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Jackie Lane'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Jean Darling'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Indiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Jean Darling'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Sepia Gloria Swanson'],
#    1934: [],
#    1935: ['Ralph Gilbert'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Minnesota': {'Wisconsin': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Alberta Vaughn'],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Billy Hayes', 'Gita Gilmore'],
#    1940: []},
#   'Minnesota': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['Frances Lee'],
#    1939: ['Terry La Monte', 'Frances Lee'],
#    1940: ['Terry La Monte', 'Frances Lee']}},
#  'Wisconsin': {'Wisconsin': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['Leon Fredericks'],
#    1934: ['Neil Dornay'],
#    1935: ['Neil Dornay'],
#    1936: ['Neil Dornay', 'Frances David'],
#    1937: ['Neil Dornay', 'Frances David', 'Johnny Blease', 'Wesley Davis'],
#    1938: ['Neil Dornay', 'Frances David', 'Johnny Blease', 'Wesley Davis'],
#    1939: ['Alberta Vaughn',
#     'Funny Fanny',
#     'Wesley Davis',
#     'Frances David',
#     'Neil Dornay',
#     'Johnny Blease'],
#    1940: ['Alberta Vaughn',
#     'Funny Fanny',
#     'Wesley Davis',
#     'Frances David',
#     'Neil Dornay',
#     'Johnny Blease']},
#   'New York': {1930: ['Frank Doran',
#     'Arthur G. West',
#     'G. Doran',
#     'Francis Renault'],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Johnny Mangum'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Florida': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Billy "Senorita" Herrera', 'Gene Dana', 'Jean Russell'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Don Rand', 'Eddie Morton', 'Frankie Stroud'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Doyle Mack'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Alabama': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Francis Renault'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Leon Fredericks'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Nina Mae McKinney'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Maryland': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Ralph Gilbert'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'New Jersey': {'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Arica Wild', 'Jackie Adams', 'Billie Davis'],
#    1934: ['Danny Brown'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New Jersey': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['Jackie Lee'],
#    1935: ['Jackie Lee'],
#    1936: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1937: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1938: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1939: ['Arica Wild', 'Jackie Lee', 'E. Russell'],
#    1940: ['Arica Wild', 'Jackie Lee', 'E. Russell']},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Carl Clewis'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Dixie DeLane'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Lyle Page'],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Missouri': {'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Art West'],
#    1936: ['Doyle Mack'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Rae Bourbon'],
#    1936: [],
#    1937: ['Johnny Mangum'],
#    1938: ['Billie Beryl', 'Rae Bourbon'],
#    1939: ['Francis Blair'],
#    1940: []},
#   'Missouri': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['Eli Madlof'],
#    1936: ['Donald Grey', 'Eli Madlof'],
#    1937: ['Donald Grey',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1938: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1939: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks'],
#    1940: ['Fay Norman',
#     'Donald Grey',
#     'Lena Rivers',
#     'Lanny Brice',
#     'Phil Craig',
#     'Billie Brannon',
#     'Peggy Joyce',
#     'Eli Madlof',
#     'Leon Fredericks']},
#   'Texas': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Lena Rivers', 'Billy Richards'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Bobbie Bell'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Wisconsin': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Frances David'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Frankie Stroud'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Gypsy Dolan'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Colorado': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Pepper Cortez'],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Ohio': {'Ohio': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['Li Kar', 'Leon La Verde'],
#    1936: ['George Hayes',
#     'Lyle Mack',
#     'Danny Brown',
#     'Leon La Verde',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Li Kar',
#     'Art West',
#     'Jerry Clayton'],
#    1937: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Leon La Verde',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Jerry Clayton',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1938: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1939: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue'],
#    1940: ['Bobbie Bell',
#     'George Hayes',
#     'Billy Irwin',
#     'Lyle Mack',
#     'Bobby Allen',
#     'Lee Carroll',
#     'Reggie "Dolly" Windsor',
#     'Doyle Mack',
#     'Jerry Faye',
#     'Dixie Dixon',
#     'Larry West',
#     'Art West',
#     'Bobby La Rue']},
#   'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Bobbie Bell'],
#    1935: [],
#    1936: [],
#    1937: ['Billie Beryl'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Minnesota': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Frances Lee'],
#    1938: ['Billy Hayes', 'Terry La Monte'],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Billy Richards'],
#    1935: [],
#    1936: [],
#    1937: ['Li Kar'],
#    1938: ['Leon La Verde'],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Billy Rohmer'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Boots Lavana'],
#    1935: [],
#    1936: ['Bobbie La Marr', 'Karyl Norman', 'Jackie Maye'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Kentucky': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Jacquette La Marr', 'Chickie Mears'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Colorado': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Danny Brown'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Funny Fanny', 'Mickey Nelson', 'Tangara', 'Del Le Roy'],
#    1937: ['Jackie Lane'],
#    1938: [],
#    1939: ['Jackie Starr', 'Karyl Norman'],
#    1940: []},
#   'Tennessee': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Fay Norman'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New Jersey': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Francis Renault'],
#    1939: [],
#    1940: []},
#   'Wisconsin': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Funny Fanny'],
#    1939: [],
#    1940: []},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Jackie Starr', 'Gita Gilmore'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Massachusetts': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Karyl Norman'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Maryland': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Verne Valdez'],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Florida': {'Maryland': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Billy "Senorita" Herrera', 'Babe Allen'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Florida': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['Donald Grey', 'Walter McDonald', 'Gene Russell'],
#    1934: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1935: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1936: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1937: ['Jean Russell', 'Walter McDonald', 'Gene Russell'],
#    1938: ['Gene Dana', 'Walter McDonald', 'Jean Russell', 'Gene Russell'],
#    1939: ['Jean Russell',
#     'Tex Hendricks',
#     'Gene Russell',
#     'Paul Russell',
#     'Bobbie La Marr',
#     'Teddy Cappy',
#     'Norman Lewis',
#     'Blackie Dennis',
#     'Johnny Mangum',
#     'Nicki Gallucci',
#     'Walter McDonald',
#     'Billy Rohmer',
#     'Pat Clayton',
#     'Lynn & Johnson',
#     'Bill Kennedy'],
#    1940: ['Billy "Senorita" Herrera',
#     'Jean Russell',
#     'Tex Hendricks',
#     'Gene Russell',
#     'Paul Russell',
#     'Bobbie La Marr',
#     'Teddy Cappy',
#     'Norman Lewis',
#     'Blackie Dennis',
#     'Johnny Mangum',
#     'Nicki Gallucci',
#     'Walter McDonald',
#     'Billy Rohmer',
#     'Pat Clayton',
#     'Lynn & Johnson',
#     'Bill Kennedy']},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Billy Rohmer'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Donald Grey'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Jackie Maye'],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Gene Dana'],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Lucian', 'Sunny La Ray', 'Peppy Carman'],
#    1940: []}},
#  'Maryland': {'Maryland': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['Mother Smother/Sepia Marlene Dietrich', 'Bert Sherry'],
#    1935: ['Billy "Senorita" Herrera', 'Bert Sherry', 'Babe Allen'],
#    1936: ['Bert Sherry', 'Mickey Dell', 'Edmund Link', 'Babe Allen'],
#    1937: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1938: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1939: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen'],
#    1940: ['Mickey Dell',
#     'Bert Sherry',
#     'Lester Lamont',
#     'Edmund Link',
#     'Babe Allen']},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Dixie Lee'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Mother Smother/Sepia Marlene Dietrich', 'Nicki Gallucci'],
#    1936: ['Jackie Adams'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Larry West'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'California': {'California': {1930: ['Jean Barrios'],
#    1931: ['Rae Bourbon'],
#    1932: ['Neil Dornay', 'Rocky twins', 'Don La Rue'],
#    1933: ['Jean Barrios', 'Rocky twins', 'Don La Rue'],
#    1934: ['Jean Barrios', 'Rocky twins', 'Don La Rue'],
#    1935: ['Jean Barrios',
#     'Rocky twins',
#     'Don La Rue',
#     'Carl Clewis',
#     'Leon Fredericks'],
#    1936: ['Jean Barrios',
#     'Rocky twins',
#     'Rae Bourbon',
#     'Don La Rue',
#     'Carl Clewis'],
#    1937: ['Jean Barrios',
#     'Johnny David',
#     'Rocky twins',
#     'Rae Bourbon',
#     'Don La Rue',
#     'Carl Clewis'],
#    1938: ['Billy "Senorita" Herrera',
#     'Jean Barrios',
#     'Johnny David',
#     'Don La Rue',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Walter Hart',
#     'Li Kar',
#     'Jerry Clayton',
#     'Carl Clewis'],
#    1939: ['Johnny David',
#     'Leon La Verde',
#     'Billie Beryl',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Jerry Clayton',
#     'Niles Marsh',
#     'Walter Hart',
#     'Li Kar',
#     'Don La Rue',
#     'Carl Clewis'],
#    1940: ['Jean Barrios',
#     'Johnny David',
#     'Leon La Verde',
#     'Jackie Maye',
#     'Freddie Renault',
#     'Reeder Richards',
#     'Francis Blair',
#     'Niles Marsh',
#     'Jackie Lopez',
#     'Rocky twins',
#     'Verne Valdez',
#     'Jerry Clayton',
#     'Billie Beryl',
#     'Walter Hart',
#     'Li Kar',
#     'Don La Rue',
#     'Carl Clewis']},
#   'Florida': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Johnny Mangum'],
#    1939: ['Billy "Senorita" Herrera'],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Bobby La Rue'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Donald Grey'],
#    1936: ['Leon Fredericks'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: ['Jean Barrios'],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Verne Valdez'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Texas': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Johnny David'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Karyl Norman'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Rae Bourbon'],
#    1940: []},
#   'Wisconsin': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Neil Dornay'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Utah': {1930: [],
#    1931: [],
#    1932: ['Rae Bourbon'],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Texas': {'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Billie Brannon'],
#    1937: ['Phil Craig'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Pennsylvania': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Billy "Senorita" Herrera'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Nevada': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Billy Richards'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Ohio': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Billy Rohmer'],
#    1936: ['Bobbie Bell', 'Lena Rivers', 'Gita Gilmore'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Texas': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['Jean Evol'],
#    1933: ['Jean Evol'],
#    1934: ['Jean Evol'],
#    1935: ['Eddie Morton',
#     'Georgie Kaye',
#     'Jean Evol',
#     'Don Rand',
#     'Gene Dana'],
#    1936: ['Phil Craig', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1937: ['Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1938: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1939: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol'],
#    1940: ['Johnny Kaye', 'Boots Lavana', 'Georgie Kaye', 'Jean Evol']},
#   'Kentucky': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Don Rand'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Eddie Morton'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Louisiana': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Gene Dana'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Florida': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Gene Dana'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Johnny David'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Washington': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Verne Valdez'],
#    1939: [],
#    1940: []}},
#  'Washington': {'California': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Billy "Senorita" Herrera'],
#    1938: [],
#    1939: ['Verne Valdez'],
#    1940: []},
#   'Nevada': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Francis Blair'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Texas': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Johnny Kaye'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Washington': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'Kentucky': {'Kentucky': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['Billy Hayes'],
#    1937: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1938: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1939: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins'],
#    1940: ['Connie Walsh',
#     'Jacquette La Marr',
#     'Don Rand',
#     'Chickie Mears',
#     'Carlo Levins']}},
#  'Nevada': {'Nevada': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['Billy Richards', 'Francis Blair'],
#    1938: ['Billy Richards', 'Francis Blair'],
#    1939: ['Billy Richards'],
#    1940: ['Billy Richards']}},
#  'Louisiana': {'Louisiana': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['Billy Rohmer'],
#    1938: ['Billy Rohmer'],
#    1939: ['filler'],
#    1940: ['filler']},
#   'Illinois': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Wesley Davis'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []}},
#  'Tennessee': {'Missouri': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: ['Fay Norman'],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Tennessee': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'West Virginia': {'Wyoming': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Francis Renault'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'West Virginia': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'Wyoming': {'New Jersey': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: ['Francis Renault'],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Michigan': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: ['Jean La Monte'],
#    1940: []},
#   'Wyoming': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'Indiana': {'Indiana': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['Jean Darling'],
#    1938: ['Jean Darling'],
#    1939: ['Jean Darling'],
#    1940: ['Jean Darling']}},
#  'Colorado': {'Colorado': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['Pepper Cortez'],
#    1939: ['Pepper Cortez'],
#    1940: ['Pepper Cortez']}},
#  'Utah': {'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: ['Rae Bourbon'],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Florida': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: ['Rae Bourbon'],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'Utah': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'North Carolina': {'Connecticut': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: ['Roni Warren'],
#    1937: [],
#    1938: [],
#    1939: [],
#    1940: []},
#   'North Carolina': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['filler'],
#    1938: ['filler'],
#    1939: ['filler'],
#    1940: ['filler']}},
#  'Connecticut': {'Connecticut': {1930: ['filler'],
#    1931: ['filler'],
#    1932: ['filler'],
#    1933: ['filler'],
#    1934: ['filler'],
#    1935: ['filler'],
#    1936: ['filler'],
#    1937: ['Roni Warren'],
#    1938: ['Terry Tremaine'],
#    1939: ['Terry Tremaine'],
#    1940: ['Terry Tremaine']},
#   'New York': {1930: [],
#    1931: [],
#    1932: [],
#    1933: [],
#    1934: [],
#    1935: [],
#    1936: [],
#    1937: [],
#    1938: ['Roni Warren'],
#    1939: [],
#    1940: []}}}

# %%
import networkx as nx
import json, datetime


G = nx.DiGraph()

# %%
for source, data in padded_travels_performers.items():
    for target, data2 in data.items():
        for year, performers in data2.items():
            count = len(performers)
            if year + 1 > 1940:
                continue
                
            node1_display = f'{source} {year}'
            node1_name = slugify(node1_display)
            
            node2_display = f'{target} {year + 1}'
            node2_name = slugify(node2_display)
            
            value = count

            print(source, target, year, value)
            
            inferred = inferred_travels.get(source, {}).get(target, {}).get(year, [])
            
            G.add_node(node1_name, display=node1_display, year=year, state=slugify(source))
            G.add_node(node2_name, display=node2_display, year=year+1, state=slugify(target))
            
# Indiana Indiana 1939 1
# Colorado Colorado 1930 1
# Colorado Colorado 1931 1
# Colorado Colorado 1932 1
# Colorado Colorado 1933 1
# Colorado Colorado 1934 1
# Colorado Colorado 1935 1
# Colorado Colorado 1936 1
# Colorado Colorado 1937 1
# Colorado Colorado 1938 1
# Colorado Colorado 1939 1
# Utah New York 1930 0
# Utah New York 1931 0
# Utah New York 1932 0
# Utah New York 1933 1
# Utah New York 1934 0
# Utah New York 1935 0
# Utah New York 1936 0
# Utah New York 1937 0
# Utah New York 1938 0
# Utah New York 1939 0
# Utah Florida 1930 0
# Utah Florida 1931 0
# Utah Florida 1932 0
# Utah Florida 1933 0
# Utah Florida 1934 1
# Utah Florida 1935 0
# Utah Florida 1936 0
# Utah Florida 1937 0
# Utah Florida 1938 0
# Utah Florida 1939 0
# Utah Utah 1930 1
# Utah Utah 1931 1
# Utah Utah 1932 1
# Utah Utah 1933 1
# Utah Utah 1934 1
# Utah Utah 1935 1
# Utah Utah 1936 1
# Utah Utah 1937 1
# Utah Utah 1938 1
# Utah Utah 1939 1
# North Carolina Connecticut 1930 0
# North Carolina Connecticut 1931 0
# North Carolina Connecticut 1932 0
# North Carolina Connecticut 1933 0
# North Carolina Connecticut 1934 0
# North Carolina Connecticut 1935 0
# North Carolina Connecticut 1936 1
# North Carolina Connecticut 1937 0
# North Carolina Connecticut 1938 0
# North Carolina Connecticut 1939 0
# North Carolina North Carolina 1930 1
# North Carolina North Carolina 1931 1
# North Carolina North Carolina 1932 1
# North Carolina North Carolina 1933 1
# North Carolina North Carolina 1934 1
# North Carolina North Carolina 1935 1
# North Carolina North Carolina 1936 1
# North Carolina North Carolina 1937 1
# North Carolina North Carolina 1938 1
# North Carolina North Carolina 1939 1
# Connecticut Connecticut 1930 1
# Connecticut Connecticut 1931 1
# Connecticut Connecticut 1932 1
# Connecticut Connecticut 1933 1
# Connecticut Connecticut 1934 1
# Connecticut Connecticut 1935 1
# Connecticut Connecticut 1936 1
# Connecticut Connecticut 1937 1
# Connecticut Connecticut 1938 1
# Connecticut Connecticut 1939 1
# Connecticut New York 1930 0
# Connecticut New York 1931 0
# Connecticut New York 1932 0
# Connecticut New York 1933 0
# Connecticut New York 1934 0
# Connecticut New York 1935 0
# Connecticut New York 1936 0
# Connecticut New York 1937 0
# Connecticut New York 1938 1
# Connecticut New York 1939 0

# %%
with open('./sankey-test/sankey-names.json', 'w+') as f:
    f.write(json.dumps({
        'nodes': nx.node_link_data(G)['nodes'],
        'links': nx.node_link_data(G)['links'],
        'paddedTravels': {
            slugify(k): {
                slugify(x): y for x,y in v.items()
            } for k, v in padded_travels_performers.items()
        },
        'saved': datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }))
    print('saved.')
    
with open('../docs/data/sankey-data.json', 'w+') as f:
    f.write(json.dumps({
        'nodes': nx.node_link_data(G)['nodes'],
        'links': nx.node_link_data(G)['links'],
        'paddedTravels': {
            slugify(k): {
                slugify(x): y for x,y in v.items()
            } for k, v in padded_travels_performers.items()
        },
        'saved': datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }))
    print('saved.')
# Out:
# saved.
# saved.
